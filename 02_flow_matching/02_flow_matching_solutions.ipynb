# %% [markdown]
# # Flow Matching
#
# This afternoon we're going to be working with the _same_ dataset as yesterday in Annalena's tutorial with binary black hole (BBH) merger, but... using a **continous normalizing flow** trained with the **flow matching loss** instead of the discrete normalizing flows from yesterday.
#
# ![](https://github.com/odsl-team/genAI-Days/blob/main/02_flow_matching/figures/Two_merging_black_holes.png?raw=1)
#
# Photo credit [ESA](https://www.esa.int/ESA_Multimedia/Images/2019/05/Two_merging_black_holes)
#
# **Resources:**
# The data loading and evaluation code is the same as yday and comes from Annalena Kofler's [data_loading](https://github.com/odsl-team/genAI-Days/blob/main/01_normalizing_flows/data_loading.ipynb) notebook.
#
# Also, some of the code / notation from this notebook comes from the following excellent flow matching tutorials:
# - Carol Cuesta's PALMS [tutorial](https://github.com/florpi/from-zero-to-generative-jax-tutorial/blob/main/2-generative.ipynb)
# - Lukas Heinrich's flow matching notebooks: [1d](https://github.com/lukasheinrich/generative_models_examples/blob/main/flowmatching/FlowMatching1D.ipynb), [2d](https://github.com/lukasheinrich/generative_models_examples/blob/main/flowmatching/FlowMatching2D.ipynb)
#
# ### Table of Contents
# 1. [Preprocessing](#Preprocessing)
# 2. [Defining the velocity field](#velocity-NN)
# 3. [The Loss function + training](#velocity-NN)
# 4. [Evaluating the probability](#prob-eval)
# 5. [Samples from the flow](#sampling)
# 6. [BONUS: Movie of the posterior evolution](#movie)
#
# Nicole Hartman
#
# ODSL GenAI Days
#
# 24 Sept 2024

# %%
# !pip install corner
# Out:
# Requirement already satisfied: corner in /usr/local/lib/python3.10/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib>=2.1 in /usr/local/lib/python3.10/dist-packages (from corner) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=2.1->corner) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1->corner) (1.16.0)

# %%
# !pip install torchdiffeq
# Out:
# Requirement already satisfied: torchdiffeq in /usr/local/lib/python3.10/dist-packages (0.2.4)
# Requirement already satisfied: torch>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from torchdiffeq) (2.4.1+cu121)
# Requirement already satisfied: scipy>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from torchdiffeq) (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from scipy>=1.4.0->torchdiffeq) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.0->torchdiffeq) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.5.0->torchdiffeq) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.5.0->torchdiffeq) (1.3.0)

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pickle
import torch
import corner

from torch.utils.data import Dataset, DataLoader, random_split

# %load_ext autoreload
# %autoreload 2

# %%
# If running on CUDA is available, use the GPU.
if torch.cuda.is_available():
    device = "cuda"
else:
    device = "cpu"

# %%
device
# Out:
# 'cuda'

# %% [markdown]
# ### Preprocessing
#
# Here we will again load and preprocess the data we generated in the notebook `data_generation.ipynb` and saved as `data/training_dataset.pkl`.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# data_folder = '../01_normalizing_flows/data'
data_folder="/content/drive/My Drive"
file_name = os.path.join(data_folder, 'dataset.pkl')

if not os.path.isfile(file_name):
    raise ValueError(f"File {file_name} does not exist, correct path or generate data set.")

with open(file_name, 'rb') as f:
    data = pickle.load(f)
print('Sucessfully loaded dataset with', len(data['hp']), 'waveforms.')
# Out:
# Sucessfully loaded dataset with 10000 waveforms.

# %% [markdown]
# Load in a pytorch Dataset and do the dataset preprocessing

# %%
class WaveformDataset(Dataset):

    def __init__(self, data):
        '''
        - data: As loaded from what we've saved from the
                data_generation nb
        '''

        parameters = torch.FloatTensor(data['masses'])

        # Standardize masses for training
        self.parameters_mean = torch.mean(parameters, axis=0)
        self.parameters_std = torch.std(parameters, axis=0)

        parameters_standardized = (parameters - self.parameters_mean) / self.parameters_std

        '''
        Pre-process waveforms:
        - truncate below f_min
        - re-package real and imaginary part
        - only use $h_+$ for simplicity
        '''
        hp = torch.tensor(data['hp'])
        f_min, T = data['f_min'], data['T']
        delta_f = 1/T

        lower_cut = int(f_min / delta_f)
        waveforms = torch.hstack([hp.real[:, lower_cut:], hp.imag[:, lower_cut:]])

        self.parameters = parameters_standardized
        self.waveforms = waveforms.float() # type-cast to torch.float32

    def __len__(self):
        return len(self.parameters)

    def __getitem__(self, idx):
        '''
        Returns:
        params, t, cond_inputs (=data)
        [which we'll be calling x,t,y in the code]
        '''
        params = self.parameters[idx]
        signal = self.waveforms[idx]

        # Add unit normal noise to the signal
        noise = torch.randn(size = signal.shape)
        data = signal + noise

        return params.to(device), data.to(device)

# Returns data in the form (params, data)
waveform_dataset = WaveformDataset(data)

# %% [markdown]
# **Note:** To be consistent w/ the FM paper, $x_t$ is the state space that is getting evolved by the NODE (here the GW masses) and $y$ is the conditioning vector, the $h_p$ strain signal.
#
# So the data comes out of the loader in the format $x$,$y$ we've also swapped the order of the data coming out of the data loader since yesterday.

# %% [markdown]
# ### Split data into train and test dataset

# %%
# Split the dataset into training and test sets
num_samples = len(waveform_dataset)
train_fraction = 0.8
num_train = int(round(train_fraction * num_samples))
num_test = num_samples - num_train
train_dataset, test_dataset = random_split(waveform_dataset, [num_train, num_test])

# The DataLoader is used in training

batch_size=64
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ## 2. Defining the velocity field <a name="velocity-NN"></a>

# %% [markdown]
# ### Conditional Normalizing Flow
#
# **Step 1:** Set up a tiny MLP going from 2d + 1d + 1170d -> 2d (to learn the velocity field),
# where the extra 1d comes from time being an input too.

# %%
import torch.nn as nn

# %%
param_dim  =waveform_dataset.parameters.shape[-1]
context_dim = waveform_dataset.waveforms.shape[-1]

in_dim = param_dim + 1 +context_dim

# %%
hidden_dim = 1024
activation_fct = nn.ELU()

'''
Q1) TO DO
'''
phi = nn.Sequential(nn.Linear(in_dim,hidden_dim),activation_fct,
                    nn.Linear(hidden_dim,hidden_dim//2),activation_fct,
                    nn.Linear(hidden_dim//2,hidden_dim//4),activation_fct,
                    nn.Linear(hidden_dim//4,param_dim),
                   ).to(device)

# %% [markdown]
# **Check the input and output dimensionality**

# %%
for x,y in train_dataloader:
    break

# %%
x.shape,y.shape
# Out:
# (torch.Size([64, 2]), torch.Size([64, 1970]))

# %%
t = torch.rand(x.shape[0],1).to(device)
X_in = torch.concatenate([x,t,y],axis=1)
X_in.shape
# Out:
# torch.Size([64, 1973])

# %%
v_t = phi(X_in)
assert v_t.shape == x.shape

# %% [markdown]
# Hopefully you'll pass this sanity check!

# %%
# What do the true masses look like?
plt.figure(figsize=(3,3))
plt.scatter(*waveform_dataset.parameters.T,1,marker='.',alpha=.1)
plt.xlabel('standardized $M_1$')
plt.ylabel('standardized $M_2$')
# Out:
# Text(0, 0.5, 'standardized $M_2$')

# %% [markdown]
# **Vizualize the velocity field before training**

# %%
fig,ax = plt.subplots(2,1,figsize=(10,5))

kwargs = dict(angles='xy',scale_units='xy', scale=50,
              headwidth=2,headlength=2,headaxislength=2,
              width=.004,color='darkgrey',alpha=.8)
ax[0].quiver(t.squeeze().cpu(),x[:,0].detach().cpu(), np.ones(t.shape[0]), v_t[:,0].detach().cpu(),
           **kwargs)
ax[1].quiver(t.squeeze().cpu(),x[:,1].detach().cpu(), np.ones(t.shape[0]), v_t[:,1].detach().cpu(),
           **kwargs)

ax[1].set_xlabel('t',fontsize=16)
ax[0].set_title(r'Velocity field $u_\theta(x,y,t)$ from NN')

ax[0].set_ylabel('M0',fontsize=16)
ax[1].set_ylabel('M1',fontsize=16)
# Out:
# Text(0, 0.5, 'M1')

# %% [markdown]
# And, our loss function (in the next step) will be optimizing these arrows!

# %% [markdown]
# ## 3. The Loss function + training <a name="velocity-NN"></a>

# %% [markdown]
# ### Training
#
# **Recap** The 3 step procedure
# 1. Express the velocity field w/ NN
#
# $$\frac{d x_t}{dt} = v_\theta (x_t, t)$$
#
# 2. Use straight line approximation
#
# $$x_t = (1-t) x_0  + tx _1 $$
#
# 3. Define the loss function
#
# $$\mathcal{L} = \mathbb{E}_{t,x_0, x_1} \left[ ||v_\theta(x_t, t) - u(x_0 , x_1, t) ||^2 \right]$$
#
# How does this picture get updated with the _conditional input_? The extra conditioning variable can just "come along for the ride" getting tacked on right after $t$.
#
# But, it's very easy to see this is "safe" b/c this whold paradigm was built around conditional flow matching being a "safe" thing to do, now we're just additing conditioning on the parametrized velocity field instead of on the targets

# %% [markdown]
# **Conditional flow training:**
#
# 1. Express the velocity field w/ NN
#
# $$\frac{d x_t}{dt} = v_\theta (x_t, t, \color{red}{y})$$
#
# 2. Use straight line approximation
#
# $$x_t = (1-t) x_0  + tx _1 $$
#
# 3. Define the loss function
#
# $$\mathcal{L} = \mathbb{E}_{t,x_0, x_1} \left[ ||v_\theta(x_t, t, \color{red}{y}) - u(x_0 , x_1, t) ||^2 \right]$$

# %% [markdown]
# **To do:** Separate the loss function calculation from the training loop

# %%
def get_losses(phi,x1,y1):
    '''
    For NN phi and given sample from the target dist
    calculate the MSE loss

    Inputs:
    - phi: The NN parametrizing the velocity field
    - x1: sample from the target (here GW masses)
    - t: time sample for eval the velocity field
    - y1: conditional inputs (GW signal)
    '''

    batch_size = x1.shape[0]

    # Sample x0 from a Gaussian and t from Uniform dist
    # Hints: torch.rand and torch.randn might
    x0 = torch.randn(*x1.shape).to(device)
    t = torch.rand(batch_size)[:,None].to(device)

    # Little sanity check dimensions are as expected
    assert x0.shape == x1.shape
    assert len(t) == batch_size

    # Use x0 and x1 to construct xt
    xt = (1-t) * x0 + t * x1

    X_in = torch.concatenate([xt,t,y1],axis=1)
    v_t = phi(X_in) # NN velocity

    u_t = x1 - x0 # target

    # Compute MSE loss
    loss = (v_t - u_t) ** 2

    return loss

# Sanity check the inputs make sense
loss = get_losses(phi,x,y)
assert loss.shape == x.shape

# %%
# ?phi

# %%
# Training and test loops

def train_loop(dataloader, model, optimizer):

    model.train()

    size = len(dataloader.dataset)
    train_loss = 0

    for batch, (x,y) in enumerate(dataloader):

        loss = get_losses(model,x,y)

        train_loss += loss.detach().sum()
        loss = loss.mean()

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 50 == 0:
            loss, current = loss.item(), batch * len(x)
            print(f"Loss: {loss:>7f}  [{current:>5d}/{size:>5d} samples]")

    average_loss = train_loss.item() / size
    print('Average loss: {:.4f}'.format(average_loss))
    return average_loss


def test_loop(dataloader, model):

    model.eval()

    size = len(dataloader.dataset)
    test_loss = 0

    with torch.no_grad():
        for x,y in dataloader:
            loss = get_losses(model,x,y)
            test_loss += loss.sum()

    test_loss = test_loss.item() / size
    print(f"Test loss: {test_loss:>8f} \n")
    return test_loss

# %%
optimizer = torch.optim.Adam(phi.parameters(), lr=1e-3, weight_decay=1e-6)

epochs = 500
train_history = []
test_history = []
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    loss = train_loop(train_dataloader, phi, optimizer)
    train_history.append(loss)
    loss = test_loop(test_dataloader, phi)
    test_history.append(loss)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# Loss: 2.145522  [    0/ 8000 samples]
# Loss: 1.011438  [ 3200/ 8000 samples]
# Loss: 1.162822  [ 6400/ 8000 samples]
# Average loss: 2.6239
# Test loss: 2.291634
#
# Epoch 2
# -------------------------------
# Loss: 1.105757  [    0/ 8000 samples]
# Loss: 1.123633  [ 3200/ 8000 samples]
# Loss: 1.247426  [ 6400/ 8000 samples]
# Average loss: 2.1833
# Test loss: 2.083090
#
# Epoch 3
# -------------------------------
# Loss: 0.915006  [    0/ 8000 samples]
# Loss: 1.259053  [ 3200/ 8000 samples]
# Loss: 0.901610  [ 6400/ 8000 samples]
# Average loss: 2.0177
# Test loss: 1.920762
#
# Epoch 4
# -------------------------------
# Loss: 1.023056  [    0/ 8000 samples]
# Loss: 0.909188  [ 3200/ 8000 samples]
# Loss: 0.888112  [ 6400/ 8000 samples]
# Average loss: 1.9026
# Test loss: 1.850648
#
# Epoch 5
# -------------------------------
# Loss: 1.050412  [    0/ 8000 samples]
# Loss: 0.747594  [ 3200/ 8000 samples]
# Loss: 0.699944  [ 6400/ 8000 samples]
# Average loss: 1.7187
# Test loss: 1.587651
#
# Epoch 6
# -------------------------------
# Loss: 0.672634  [    0/ 8000 samples]
# Loss: 0.768697  [ 3200/ 8000 samples]
# Loss: 0.828241  [ 6400/ 8000 samples]
# Average loss: 1.5023
# Test loss: 1.411141
#
# Epoch 7
# -------------------------------
# Loss: 0.749434  [    0/ 8000 samples]
# Loss: 0.649251  [ 3200/ 8000 samples]
# Loss: 0.822188  [ 6400/ 8000 samples]
# Average loss: 1.4190
# Test loss: 1.345304
#
# Epoch 8
# -------------------------------
# Loss: 0.624125  [    0/ 8000 samples]
# Loss: 0.640006  [ 3200/ 8000 samples]
# Loss: 0.641044  [ 6400/ 8000 samples]
# Average loss: 1.2814
# Test loss: 1.155015
#
# Epoch 9
# -------------------------------
# Loss: 0.727517  [    0/ 8000 samples]
# Loss: 0.705314  [ 3200/ 8000 samples]
# Loss: 0.557174  [ 6400/ 8000 samples]
# Average loss: 1.2295
# Test loss: 1.075614
#
# Epoch 10
# -------------------------------
# Loss: 0.565125  [    0/ 8000 samples]
# Loss: 0.486396  [ 3200/ 8000 samples]
# Loss: 0.629498  [ 6400/ 8000 samples]
# Average loss: 1.1385
# Test loss: 0.982989
#
# Epoch 11
# -------------------------------
# Loss: 0.679350  [    0/ 8000 samples]
# Loss: 0.509149  [ 3200/ 8000 samples]
# Loss: 0.528376  [ 6400/ 8000 samples]
# Average loss: 1.0371
# Test loss: 0.974087
#
# Epoch 12
# -------------------------------
# Loss: 0.582183  [    0/ 8000 samples]
# Loss: 0.472397  [ 3200/ 8000 samples]
# Loss: 0.546703  [ 6400/ 8000 samples]
# Average loss: 0.9999
# Test loss: 0.975790
#
# Epoch 13
# -------------------------------
# Loss: 0.428901  [    0/ 8000 samples]
# Loss: 0.504762  [ 3200/ 8000 samples]
# Loss: 0.512648  [ 6400/ 8000 samples]
# Average loss: 1.0045
# Test loss: 0.954981
#
# Epoch 14
# -------------------------------
# Loss: 0.615378  [    0/ 8000 samples]
# Loss: 0.612515  [ 3200/ 8000 samples]
# Loss: 0.422620  [ 6400/ 8000 samples]
# Average loss: 0.9754
# Test loss: 1.041376
#
# Epoch 15
# -------------------------------
# Loss: 0.433553  [    0/ 8000 samples]
# Loss: 0.583153  [ 3200/ 8000 samples]
# Loss: 0.541139  [ 6400/ 8000 samples]
# Average loss: 1.0048
# Test loss: 0.973250
#
# Epoch 16
# -------------------------------
# Loss: 0.497841  [    0/ 8000 samples]
# Loss: 0.377909  [ 3200/ 8000 samples]
# Loss: 0.624070  [ 6400/ 8000 samples]
# Average loss: 0.9560
# Test loss: 1.103268
#
# Epoch 17
# -------------------------------
# Loss: 0.448965  [    0/ 8000 samples]
# Loss: 0.399083  [ 3200/ 8000 samples]
# Loss: 0.454064  [ 6400/ 8000 samples]
# Average loss: 0.9520
# Test loss: 0.869319
#
# Epoch 18
# -------------------------------
# Loss: 0.512155  [    0/ 8000 samples]
# Loss: 0.490421  [ 3200/ 8000 samples]
# Loss: 0.515550  [ 6400/ 8000 samples]
# Average loss: 0.9178
# Test loss: 0.916838
#
# Epoch 19
# -------------------------------
# Loss: 0.404005  [    0/ 8000 samples]
# Loss: 0.580090  [ 3200/ 8000 samples]
# Loss: 0.416995  [ 6400/ 8000 samples]
# Average loss: 0.9216
# Test loss: 0.869337
#
# Epoch 20
# -------------------------------
# Loss: 0.533739  [    0/ 8000 samples]
# Loss: 0.446265  [ 3200/ 8000 samples]
# Loss: 0.441174  [ 6400/ 8000 samples]
# Average loss: 0.8888
# Test loss: 0.833663
#
# Epoch 21
# -------------------------------
# Loss: 0.342505  [    0/ 8000 samples]
# Loss: 0.491010  [ 3200/ 8000 samples]
# Loss: 0.391856  [ 6400/ 8000 samples]
# Average loss: 0.8869
# Test loss: 0.961561
#
# Epoch 22
# -------------------------------
# Loss: 0.563415  [    0/ 8000 samples]
# Loss: 0.402777  [ 3200/ 8000 samples]
# Loss: 0.451893  [ 6400/ 8000 samples]
# Average loss: 0.8716
# Test loss: 0.902415
#
# Epoch 23
# -------------------------------
# Loss: 0.526351  [    0/ 8000 samples]
# Loss: 0.405221  [ 3200/ 8000 samples]
# Loss: 0.496217  [ 6400/ 8000 samples]
# Average loss: 0.8724
# Test loss: 0.869485
#
# Epoch 24
# -------------------------------
# Loss: 0.378363  [    0/ 8000 samples]
# Loss: 0.450499  [ 3200/ 8000 samples]
# Loss: 0.471077  [ 6400/ 8000 samples]
# Average loss: 0.8547
# Test loss: 0.829909
#
# Epoch 25
# -------------------------------
# Loss: 0.636594  [    0/ 8000 samples]
# Loss: 0.355954  [ 3200/ 8000 samples]
# Loss: 0.342912  [ 6400/ 8000 samples]
# Average loss: 0.8513
# Test loss: 0.857479
#
# Epoch 26
# -------------------------------
# Loss: 0.470568  [    0/ 8000 samples]
# Loss: 0.426356  [ 3200/ 8000 samples]
# Loss: 0.445457  [ 6400/ 8000 samples]
# Average loss: 0.8589
# Test loss: 0.848451
#
# Epoch 27
# -------------------------------
# Loss: 0.408504  [    0/ 8000 samples]
# Loss: 0.356788  [ 3200/ 8000 samples]
# Loss: 0.458411  [ 6400/ 8000 samples]
# Average loss: 0.8526
# Test loss: 0.761718
#
# Epoch 28
# -------------------------------
# Loss: 0.464092  [    0/ 8000 samples]
# Loss: 0.523497  [ 3200/ 8000 samples]
# Loss: 0.520795  [ 6400/ 8000 samples]
# Average loss: 0.7859
# Test loss: 0.792124
#
# Epoch 29
# -------------------------------
# Loss: 0.417827  [    0/ 8000 samples]
# Loss: 0.362184  [ 3200/ 8000 samples]
# Loss: 0.450151  [ 6400/ 8000 samples]
# Average loss: 0.8000
# Test loss: 0.852147
#
# Epoch 30
# -------------------------------
# Loss: 0.356549  [    0/ 8000 samples]
# Loss: 0.453325  [ 3200/ 8000 samples]
# Loss: 0.392420  [ 6400/ 8000 samples]
# Average loss: 0.8363
# Test loss: 0.832793
#
# Epoch 31
# -------------------------------
# Loss: 0.403922  [    0/ 8000 samples]
# Loss: 0.448036  [ 3200/ 8000 samples]
# Loss: 0.417502  [ 6400/ 8000 samples]
# Average loss: 0.8370
# Test loss: 0.823723
#
# Epoch 32
# -------------------------------
# Loss: 0.316758  [    0/ 8000 samples]
# Loss: 0.374188  [ 3200/ 8000 samples]
# Loss: 0.461093  [ 6400/ 8000 samples]
# Average loss: 0.8390
# Test loss: 0.788323
#
# Epoch 33
# -------------------------------
# Loss: 0.413557  [    0/ 8000 samples]
# Loss: 0.311915  [ 3200/ 8000 samples]
# Loss: 0.263659  [ 6400/ 8000 samples]
# Average loss: 0.8216
# Test loss: 0.806956
#
# Epoch 34
# -------------------------------
# Loss: 0.434729  [    0/ 8000 samples]
# Loss: 0.506312  [ 3200/ 8000 samples]
# Loss: 0.360645  [ 6400/ 8000 samples]
# Average loss: 0.8129
# Test loss: 0.738006
#
# Epoch 35
# -------------------------------
# Loss: 0.383514  [    0/ 8000 samples]
# Loss: 0.545180  [ 3200/ 8000 samples]
# Loss: 0.471959  [ 6400/ 8000 samples]
# Average loss: 0.8006
# Test loss: 0.740509
#
# Epoch 36
# -------------------------------
# Loss: 0.337873  [    0/ 8000 samples]
# Loss: 0.423602  [ 3200/ 8000 samples]
# Loss: 0.337476  [ 6400/ 8000 samples]
# Average loss: 0.7692
# Test loss: 0.744580
#
# Epoch 37
# -------------------------------
# Loss: 0.470276  [    0/ 8000 samples]
# Loss: 0.320634  [ 3200/ 8000 samples]
# Loss: 0.372126  [ 6400/ 8000 samples]
# Average loss: 0.7536
# Test loss: 0.768957
#
# Epoch 38
# -------------------------------
# Loss: 0.447039  [    0/ 8000 samples]
# Loss: 0.345927  [ 3200/ 8000 samples]
# Loss: 0.345615  [ 6400/ 8000 samples]
# Average loss: 0.7782
# Test loss: 0.814955
#
# Epoch 39
# -------------------------------
# Loss: 0.500926  [    0/ 8000 samples]
# Loss: 0.311220  [ 3200/ 8000 samples]
# Loss: 0.517692  [ 6400/ 8000 samples]
# Average loss: 0.7808
# Test loss: 0.783450
#
# Epoch 40
# -------------------------------
# Loss: 0.368373  [    0/ 8000 samples]
# Loss: 0.494675  [ 3200/ 8000 samples]
# Loss: 0.311342  [ 6400/ 8000 samples]
# Average loss: 0.7531
# Test loss: 0.794998
#
# Epoch 41
# -------------------------------
# Loss: 0.396343  [    0/ 8000 samples]
# Loss: 0.315945  [ 3200/ 8000 samples]
# Loss: 0.356360  [ 6400/ 8000 samples]
# Average loss: 0.7426
# Test loss: 0.717898
#
# Epoch 42
# -------------------------------
# Loss: 0.445771  [    0/ 8000 samples]
# Loss: 0.465453  [ 3200/ 8000 samples]
# Loss: 0.319113  [ 6400/ 8000 samples]
# Average loss: 0.7698
# Test loss: 0.750210
#
# Epoch 43
# -------------------------------
# Loss: 0.432612  [    0/ 8000 samples]
# Loss: 0.302529  [ 3200/ 8000 samples]
# Loss: 0.464370  [ 6400/ 8000 samples]
# Average loss: 0.7617
# Test loss: 0.703411
#
# Epoch 44
# -------------------------------
# Loss: 0.424328  [    0/ 8000 samples]
# Loss: 0.563828  [ 3200/ 8000 samples]
# Loss: 0.403072  [ 6400/ 8000 samples]
# Average loss: 0.7445
# Test loss: 0.771184
#
# Epoch 45
# -------------------------------
# Loss: 0.386659  [    0/ 8000 samples]
# Loss: 0.417603  [ 3200/ 8000 samples]
# Loss: 0.389517  [ 6400/ 8000 samples]
# Average loss: 0.7517
# Test loss: 0.749094
#
# Epoch 46
# -------------------------------
# Loss: 0.375104  [    0/ 8000 samples]
# Loss: 0.324853  [ 3200/ 8000 samples]
# Loss: 0.237307  [ 6400/ 8000 samples]
# Average loss: 0.7259
# Test loss: 0.709260
#
# Epoch 47
# -------------------------------
# Loss: 0.464033  [    0/ 8000 samples]
# Loss: 0.342413  [ 3200/ 8000 samples]
# Loss: 0.532787  [ 6400/ 8000 samples]
# Average loss: 0.7343
# Test loss: 0.775575
#
# Epoch 48
# -------------------------------
# Loss: 0.539700  [    0/ 8000 samples]
# Loss: 0.402435  [ 3200/ 8000 samples]
# Loss: 0.345089  [ 6400/ 8000 samples]
# Average loss: 0.7283
# Test loss: 0.796352
#
# Epoch 49
# -------------------------------
# Loss: 0.288132  [    0/ 8000 samples]
# Loss: 0.310649  [ 3200/ 8000 samples]
# Loss: 0.348871  [ 6400/ 8000 samples]
# Average loss: 0.7268
# Test loss: 0.699549
#
# Epoch 50
# -------------------------------
# Loss: 0.382315  [    0/ 8000 samples]
# Loss: 0.273218  [ 3200/ 8000 samples]
# Loss: 0.303525  [ 6400/ 8000 samples]
# Average loss: 0.7105
# Test loss: 0.677104
#
# Epoch 51
# -------------------------------
# Loss: 0.448569  [    0/ 8000 samples]
# Loss: 0.477056  [ 3200/ 8000 samples]
# Loss: 0.367442  [ 6400/ 8000 samples]
# Average loss: 0.7113
# Test loss: 0.799092
#
# Epoch 52
# -------------------------------
# Loss: 0.357687  [    0/ 8000 samples]
# Loss: 0.274231  [ 3200/ 8000 samples]
# Loss: 0.224346  [ 6400/ 8000 samples]
# Average loss: 0.7241
# Test loss: 0.768033
#
# Epoch 53
# -------------------------------
# Loss: 0.413611  [    0/ 8000 samples]
# Loss: 0.493270  [ 3200/ 8000 samples]
# Loss: 0.381810  [ 6400/ 8000 samples]
# Average loss: 0.7153
# Test loss: 0.688830
#
# Epoch 54
# -------------------------------
# Loss: 0.296042  [    0/ 8000 samples]
# Loss: 0.345810  [ 3200/ 8000 samples]
# Loss: 0.311148  [ 6400/ 8000 samples]
# Average loss: 0.6810
# Test loss: 0.641789
#
# Epoch 55
# -------------------------------
# Loss: 0.406477  [    0/ 8000 samples]
# Loss: 0.372701  [ 3200/ 8000 samples]
# Loss: 0.353647  [ 6400/ 8000 samples]
# Average loss: 0.7072
# Test loss: 0.790302
#
# Epoch 56
# -------------------------------
# Loss: 0.418774  [    0/ 8000 samples]
# Loss: 0.404926  [ 3200/ 8000 samples]
# Loss: 0.361654  [ 6400/ 8000 samples]
# Average loss: 0.6885
# Test loss: 0.711244
#
# Epoch 57
# -------------------------------
# Loss: 0.247357  [    0/ 8000 samples]
# Loss: 0.242731  [ 3200/ 8000 samples]
# Loss: 0.442107  [ 6400/ 8000 samples]
# Average loss: 0.6995
# Test loss: 0.704569
#
# Epoch 58
# -------------------------------
# Loss: 0.454540  [    0/ 8000 samples]
# Loss: 0.334678  [ 3200/ 8000 samples]
# Loss: 0.355894  [ 6400/ 8000 samples]
# Average loss: 0.6542
# Test loss: 0.634200
#
# Epoch 59
# -------------------------------
# Loss: 0.255729  [    0/ 8000 samples]
# Loss: 0.285083  [ 3200/ 8000 samples]
# Loss: 0.362976  [ 6400/ 8000 samples]
# Average loss: 0.6545
# Test loss: 0.621730
#
# Epoch 60
# -------------------------------
# Loss: 0.411635  [    0/ 8000 samples]
# Loss: 0.362833  [ 3200/ 8000 samples]
# Loss: 0.465390  [ 6400/ 8000 samples]
# Average loss: 0.7005
# Test loss: 0.666439
#
# Epoch 61
# -------------------------------
# Loss: 0.256666  [    0/ 8000 samples]
# Loss: 0.360641  [ 3200/ 8000 samples]
# Loss: 0.329928  [ 6400/ 8000 samples]
# Average loss: 0.6764
# Test loss: 0.637238
#
# Epoch 62
# -------------------------------
# Loss: 0.457660  [    0/ 8000 samples]
# Loss: 0.228144  [ 3200/ 8000 samples]
# Loss: 0.244765  [ 6400/ 8000 samples]
# Average loss: 0.6401
# Test loss: 0.621573
#
# Epoch 63
# -------------------------------
# Loss: 0.278308  [    0/ 8000 samples]
# Loss: 0.296965  [ 3200/ 8000 samples]
# Loss: 0.227468  [ 6400/ 8000 samples]
# Average loss: 0.6266
# Test loss: 0.656059
#
# Epoch 64
# -------------------------------
# Loss: 0.463912  [    0/ 8000 samples]
# Loss: 0.215268  [ 3200/ 8000 samples]
# Loss: 0.359582  [ 6400/ 8000 samples]
# Average loss: 0.6739
# Test loss: 0.585513
#
# Epoch 65
# -------------------------------
# Loss: 0.289421  [    0/ 8000 samples]
# Loss: 0.205633  [ 3200/ 8000 samples]
# Loss: 0.200401  [ 6400/ 8000 samples]
# Average loss: 0.6260
# Test loss: 0.586500
#
# Epoch 66
# -------------------------------
# Loss: 0.384376  [    0/ 8000 samples]
# Loss: 0.253753  [ 3200/ 8000 samples]
# Loss: 0.387903  [ 6400/ 8000 samples]
# Average loss: 0.6215
# Test loss: 0.567307
#
# Epoch 67
# -------------------------------
# Loss: 0.253469  [    0/ 8000 samples]
# Loss: 0.320586  [ 3200/ 8000 samples]
# Loss: 0.316357  [ 6400/ 8000 samples]
# Average loss: 0.6135
# Test loss: 0.581220
#
# Epoch 68
# -------------------------------
# Loss: 0.350929  [    0/ 8000 samples]
# Loss: 0.282777  [ 3200/ 8000 samples]
# Loss: 0.427107  [ 6400/ 8000 samples]
# Average loss: 0.5856
# Test loss: 0.662343
#
# Epoch 69
# -------------------------------
# Loss: 0.315713  [    0/ 8000 samples]
# Loss: 0.287244  [ 3200/ 8000 samples]
# Loss: 0.201601  [ 6400/ 8000 samples]
# Average loss: 0.5939
# Test loss: 0.577904
#
# Epoch 70
# -------------------------------
# Loss: 0.488121  [    0/ 8000 samples]
# Loss: 0.421052  [ 3200/ 8000 samples]
# Loss: 0.457586  [ 6400/ 8000 samples]
# Average loss: 0.6315
# Test loss: 0.610095
#
# Epoch 71
# -------------------------------
# Loss: 0.323127  [    0/ 8000 samples]
# Loss: 0.184167  [ 3200/ 8000 samples]
# Loss: 0.255888  [ 6400/ 8000 samples]
# Average loss: 0.6236
# Test loss: 0.561200
#
# Epoch 72
# -------------------------------
# Loss: 0.368912  [    0/ 8000 samples]
# Loss: 0.236238  [ 3200/ 8000 samples]
# Loss: 0.339396  [ 6400/ 8000 samples]
# Average loss: 0.5978
# Test loss: 0.542173
#
# Epoch 73
# -------------------------------
# Loss: 0.264585  [    0/ 8000 samples]
# Loss: 0.278983  [ 3200/ 8000 samples]
# Loss: 0.220421  [ 6400/ 8000 samples]
# Average loss: 0.5871
# Test loss: 0.531353
#
# Epoch 74
# -------------------------------
# Loss: 0.247333  [    0/ 8000 samples]
# Loss: 0.221707  [ 3200/ 8000 samples]
# Loss: 0.225207  [ 6400/ 8000 samples]
# Average loss: 0.5729
# Test loss: 0.623855
#
# Epoch 75
# -------------------------------
# Loss: 0.277601  [    0/ 8000 samples]
# Loss: 0.314352  [ 3200/ 8000 samples]
# Loss: 0.225373  [ 6400/ 8000 samples]
# Average loss: 0.5424
# Test loss: 0.509526
#
# Epoch 76
# -------------------------------
# Loss: 0.259399  [    0/ 8000 samples]
# Loss: 0.237233  [ 3200/ 8000 samples]
# Loss: 0.308336  [ 6400/ 8000 samples]
# Average loss: 0.5750
# Test loss: 0.604345
#
# Epoch 77
# -------------------------------
# Loss: 0.244529  [    0/ 8000 samples]
# Loss: 0.270452  [ 3200/ 8000 samples]
# Loss: 0.191391  [ 6400/ 8000 samples]
# Average loss: 0.5336
# Test loss: 0.604807
#
# Epoch 78
# -------------------------------
# Loss: 0.248860  [    0/ 8000 samples]
# Loss: 0.418557  [ 3200/ 8000 samples]
# Loss: 0.315625  [ 6400/ 8000 samples]
# Average loss: 0.5722
# Test loss: 0.572833
#
# Epoch 79
# -------------------------------
# Loss: 0.263587  [    0/ 8000 samples]
# Loss: 0.231574  [ 3200/ 8000 samples]
# Loss: 0.335682  [ 6400/ 8000 samples]
# Average loss: 0.5774
# Test loss: 0.544111
#
# Epoch 80
# -------------------------------
# Loss: 0.351015  [    0/ 8000 samples]
# Loss: 0.266188  [ 3200/ 8000 samples]
# Loss: 0.388799  [ 6400/ 8000 samples]
# Average loss: 0.5823
# Test loss: 0.553924
#
# Epoch 81
# -------------------------------
# Loss: 0.250562  [    0/ 8000 samples]
# Loss: 0.171029  [ 3200/ 8000 samples]
# Loss: 0.303193  [ 6400/ 8000 samples]
# Average loss: 0.5649
# Test loss: 0.552719
#
# Epoch 82
# -------------------------------
# Loss: 0.269549  [    0/ 8000 samples]
# Loss: 0.199794  [ 3200/ 8000 samples]
# Loss: 0.282277  [ 6400/ 8000 samples]
# Average loss: 0.5522
# Test loss: 0.552151
#
# Epoch 83
# -------------------------------
# Loss: 0.288461  [    0/ 8000 samples]
# Loss: 0.196383  [ 3200/ 8000 samples]
# Loss: 0.378353  [ 6400/ 8000 samples]
# Average loss: 0.5580
# Test loss: 0.485037
#
# Epoch 84
# -------------------------------
# Loss: 0.266511  [    0/ 8000 samples]
# Loss: 0.259367  [ 3200/ 8000 samples]
# Loss: 0.370857  [ 6400/ 8000 samples]
# Average loss: 0.5446
# Test loss: 0.548230
#
# Epoch 85
# -------------------------------
# Loss: 0.303079  [    0/ 8000 samples]
# Loss: 0.308480  [ 3200/ 8000 samples]
# Loss: 0.354285  [ 6400/ 8000 samples]
# Average loss: 0.5343
# Test loss: 0.541450
#
# Epoch 86
# -------------------------------
# Loss: 0.195306  [    0/ 8000 samples]
# Loss: 0.228988  [ 3200/ 8000 samples]
# Loss: 0.281671  [ 6400/ 8000 samples]
# Average loss: 0.5204
# Test loss: 0.561161
#
# Epoch 87
# -------------------------------
# Loss: 0.259374  [    0/ 8000 samples]
# Loss: 0.224683  [ 3200/ 8000 samples]
# Loss: 0.262964  [ 6400/ 8000 samples]
# Average loss: 0.5418
# Test loss: 0.522522
#
# Epoch 88
# -------------------------------
# Loss: 0.249216  [    0/ 8000 samples]
# Loss: 0.157191  [ 3200/ 8000 samples]
# Loss: 0.176252  [ 6400/ 8000 samples]
# Average loss: 0.5373
# Test loss: 0.511802
#
# Epoch 89
# -------------------------------
# Loss: 0.295580  [    0/ 8000 samples]
# Loss: 0.225565  [ 3200/ 8000 samples]
# Loss: 0.229075  [ 6400/ 8000 samples]
# Average loss: 0.5157
# Test loss: 0.583431
#
# Epoch 90
# -------------------------------
# Loss: 0.320163  [    0/ 8000 samples]
# Loss: 0.179811  [ 3200/ 8000 samples]
# Loss: 0.192291  [ 6400/ 8000 samples]
# Average loss: 0.5194
# Test loss: 0.485241
#
# Epoch 91
# -------------------------------
# Loss: 0.263955  [    0/ 8000 samples]
# Loss: 0.216546  [ 3200/ 8000 samples]
# Loss: 0.123639  [ 6400/ 8000 samples]
# Average loss: 0.4937
# Test loss: 0.553844
#
# Epoch 92
# -------------------------------
# Loss: 0.214257  [    0/ 8000 samples]
# Loss: 0.242210  [ 3200/ 8000 samples]
# Loss: 0.474668  [ 6400/ 8000 samples]
# Average loss: 0.5647
# Test loss: 0.606596
#
# Epoch 93
# -------------------------------
# Loss: 0.291935  [    0/ 8000 samples]
# Loss: 0.298026  [ 3200/ 8000 samples]
# Loss: 0.232581  [ 6400/ 8000 samples]
# Average loss: 0.5296
# Test loss: 0.500583
#
# Epoch 94
# -------------------------------
# Loss: 0.241231  [    0/ 8000 samples]
# Loss: 0.193822  [ 3200/ 8000 samples]
# Loss: 0.347100  [ 6400/ 8000 samples]
# Average loss: 0.5308
# Test loss: 0.561906
#
# Epoch 95
# -------------------------------
# Loss: 0.378834  [    0/ 8000 samples]
# Loss: 0.208150  [ 3200/ 8000 samples]
# Loss: 0.214567  [ 6400/ 8000 samples]
# Average loss: 0.5281
# Test loss: 0.489161
#
# Epoch 96
# -------------------------------
# Loss: 0.263850  [    0/ 8000 samples]
# Loss: 0.236113  [ 3200/ 8000 samples]
# Loss: 0.241250  [ 6400/ 8000 samples]
# Average loss: 0.5066
# Test loss: 0.561262
#
# Epoch 97
# -------------------------------
# Loss: 0.273423  [    0/ 8000 samples]
# Loss: 0.192224  [ 3200/ 8000 samples]
# Loss: 0.267407  [ 6400/ 8000 samples]
# Average loss: 0.5108
# Test loss: 0.543038
#
# Epoch 98
# -------------------------------
# Loss: 0.369516  [    0/ 8000 samples]
# Loss: 0.273296  [ 3200/ 8000 samples]
# Loss: 0.234604  [ 6400/ 8000 samples]
# Average loss: 0.4911
# Test loss: 0.526604
#
# Epoch 99
# -------------------------------
# Loss: 0.277407  [    0/ 8000 samples]
# Loss: 0.249091  [ 3200/ 8000 samples]
# Loss: 0.257814  [ 6400/ 8000 samples]
# Average loss: 0.4971
# Test loss: 0.514020
#
# Epoch 100
# -------------------------------
# Loss: 0.267236  [    0/ 8000 samples]
# Loss: 0.181960  [ 3200/ 8000 samples]
# Loss: 0.265928  [ 6400/ 8000 samples]
# Average loss: 0.4882
# Test loss: 0.447293
#
# Epoch 101
# -------------------------------
# Loss: 0.230655  [    0/ 8000 samples]
# Loss: 0.371188  [ 3200/ 8000 samples]
# Loss: 0.189782  [ 6400/ 8000 samples]
# Average loss: 0.4957
# Test loss: 0.469563
#
# Epoch 102
# -------------------------------
# Loss: 0.238447  [    0/ 8000 samples]
# Loss: 0.286366  [ 3200/ 8000 samples]
# Loss: 0.225971  [ 6400/ 8000 samples]
# Average loss: 0.4894
# Test loss: 0.422494
#
# Epoch 103
# -------------------------------
# Loss: 0.452491  [    0/ 8000 samples]
# Loss: 0.326779  [ 3200/ 8000 samples]
# Loss: 0.167818  [ 6400/ 8000 samples]
# Average loss: 0.5034
# Test loss: 0.486683
#
# Epoch 104
# -------------------------------
# Loss: 0.287562  [    0/ 8000 samples]
# Loss: 0.183288  [ 3200/ 8000 samples]
# Loss: 0.199779  [ 6400/ 8000 samples]
# Average loss: 0.4779
# Test loss: 0.531747
#
# Epoch 105
# -------------------------------
# Loss: 0.265427  [    0/ 8000 samples]
# Loss: 0.193137  [ 3200/ 8000 samples]
# Loss: 0.154044  [ 6400/ 8000 samples]
# Average loss: 0.5128
# Test loss: 0.442265
#
# Epoch 106
# -------------------------------
# Loss: 0.247042  [    0/ 8000 samples]
# Loss: 0.333774  [ 3200/ 8000 samples]
# Loss: 0.186735  [ 6400/ 8000 samples]
# Average loss: 0.4727
# Test loss: 0.473561
#
# Epoch 107
# -------------------------------
# Loss: 0.230816  [    0/ 8000 samples]
# Loss: 0.222950  [ 3200/ 8000 samples]
# Loss: 0.285032  [ 6400/ 8000 samples]
# Average loss: 0.4931
# Test loss: 0.467765
#
# Epoch 108
# -------------------------------
# Loss: 0.155309  [    0/ 8000 samples]
# Loss: 0.150148  [ 3200/ 8000 samples]
# Loss: 0.144469  [ 6400/ 8000 samples]
# Average loss: 0.4772
# Test loss: 0.502540
#
# Epoch 109
# -------------------------------
# Loss: 0.239523  [    0/ 8000 samples]
# Loss: 0.180619  [ 3200/ 8000 samples]
# Loss: 0.239794  [ 6400/ 8000 samples]
# Average loss: 0.4821
# Test loss: 0.464225
#
# Epoch 110
# -------------------------------
# Loss: 0.303955  [    0/ 8000 samples]
# Loss: 0.109489  [ 3200/ 8000 samples]
# Loss: 0.309085  [ 6400/ 8000 samples]
# Average loss: 0.4749
# Test loss: 0.450527
#
# Epoch 111
# -------------------------------
# Loss: 0.220848  [    0/ 8000 samples]
# Loss: 0.215425  [ 3200/ 8000 samples]
# Loss: 0.212460  [ 6400/ 8000 samples]
# Average loss: 0.4886
# Test loss: 0.511663
#
# Epoch 112
# -------------------------------
# Loss: 0.195332  [    0/ 8000 samples]
# Loss: 0.325652  [ 3200/ 8000 samples]
# Loss: 0.401784  [ 6400/ 8000 samples]
# Average loss: 0.4901
# Test loss: 0.460054
#
# Epoch 113
# -------------------------------
# Loss: 0.195826  [    0/ 8000 samples]
# Loss: 0.295020  [ 3200/ 8000 samples]
# Loss: 0.215222  [ 6400/ 8000 samples]
# Average loss: 0.4960
# Test loss: 0.442941
#
# Epoch 114
# -------------------------------
# Loss: 0.258966  [    0/ 8000 samples]
# Loss: 0.195686  [ 3200/ 8000 samples]
# Loss: 0.171663  [ 6400/ 8000 samples]
# Average loss: 0.4980
# Test loss: 0.468327
#
# Epoch 115
# -------------------------------
# Loss: 0.188702  [    0/ 8000 samples]
# Loss: 0.144847  [ 3200/ 8000 samples]
# Loss: 0.224343  [ 6400/ 8000 samples]
# Average loss: 0.4812
# Test loss: 0.467033
#
# Epoch 116
# -------------------------------
# Loss: 0.173185  [    0/ 8000 samples]
# Loss: 0.229096  [ 3200/ 8000 samples]
# Loss: 0.255790  [ 6400/ 8000 samples]
# Average loss: 0.4626
# Test loss: 0.475977
#
# Epoch 117
# -------------------------------
# Loss: 0.284500  [    0/ 8000 samples]
# Loss: 0.132987  [ 3200/ 8000 samples]
# Loss: 0.231462  [ 6400/ 8000 samples]
# Average loss: 0.4547
# Test loss: 0.460420
#
# Epoch 118
# -------------------------------
# Loss: 0.204865  [    0/ 8000 samples]
# Loss: 0.373134  [ 3200/ 8000 samples]
# Loss: 0.152517  [ 6400/ 8000 samples]
# Average loss: 0.4634
# Test loss: 0.455155
#
# Epoch 119
# -------------------------------
# Loss: 0.177527  [    0/ 8000 samples]
# Loss: 0.228107  [ 3200/ 8000 samples]
# Loss: 0.137460  [ 6400/ 8000 samples]
# Average loss: 0.4473
# Test loss: 0.462957
#
# Epoch 120
# -------------------------------
# Loss: 0.210019  [    0/ 8000 samples]
# Loss: 0.230833  [ 3200/ 8000 samples]
# Loss: 0.356499  [ 6400/ 8000 samples]
# Average loss: 0.4649
# Test loss: 0.453312
#
# Epoch 121
# -------------------------------
# Loss: 0.246221  [    0/ 8000 samples]
# Loss: 0.260405  [ 3200/ 8000 samples]
# Loss: 0.241388  [ 6400/ 8000 samples]
# Average loss: 0.4463
# Test loss: 0.474406
#
# Epoch 122
# -------------------------------
# Loss: 0.255023  [    0/ 8000 samples]
# Loss: 0.153758  [ 3200/ 8000 samples]
# Loss: 0.129376  [ 6400/ 8000 samples]
# Average loss: 0.4832
# Test loss: 0.430704
#
# Epoch 123
# -------------------------------
# Loss: 0.243228  [    0/ 8000 samples]
# Loss: 0.191204  [ 3200/ 8000 samples]
# Loss: 0.198218  [ 6400/ 8000 samples]
# Average loss: 0.4485
# Test loss: 0.480458
#
# Epoch 124
# -------------------------------
# Loss: 0.180920  [    0/ 8000 samples]
# Loss: 0.251480  [ 3200/ 8000 samples]
# Loss: 0.267551  [ 6400/ 8000 samples]
# Average loss: 0.4515
# Test loss: 0.462814
#
# Epoch 125
# -------------------------------
# Loss: 0.312138  [    0/ 8000 samples]
# Loss: 0.209600  [ 3200/ 8000 samples]
# Loss: 0.296077  [ 6400/ 8000 samples]
# Average loss: 0.4890
# Test loss: 0.467154
#
# Epoch 126
# -------------------------------
# Loss: 0.198269  [    0/ 8000 samples]
# Loss: 0.230671  [ 3200/ 8000 samples]
# Loss: 0.270050  [ 6400/ 8000 samples]
# Average loss: 0.4854
# Test loss: 0.519119
#
# Epoch 127
# -------------------------------
# Loss: 0.196975  [    0/ 8000 samples]
# Loss: 0.150739  [ 3200/ 8000 samples]
# Loss: 0.329150  [ 6400/ 8000 samples]
# Average loss: 0.4536
# Test loss: 0.431971
#
# Epoch 128
# -------------------------------
# Loss: 0.228920  [    0/ 8000 samples]
# Loss: 0.272953  [ 3200/ 8000 samples]
# Loss: 0.154699  [ 6400/ 8000 samples]
# Average loss: 0.4506
# Test loss: 0.399726
#
# Epoch 129
# -------------------------------
# Loss: 0.119741  [    0/ 8000 samples]
# Loss: 0.142308  [ 3200/ 8000 samples]
# Loss: 0.480501  [ 6400/ 8000 samples]
# Average loss: 0.4601
# Test loss: 0.498706
#
# Epoch 130
# -------------------------------
# Loss: 0.313477  [    0/ 8000 samples]
# Loss: 0.103113  [ 3200/ 8000 samples]
# Loss: 0.213062  [ 6400/ 8000 samples]
# Average loss: 0.4441
# Test loss: 0.527478
#
# Epoch 131
# -------------------------------
# Loss: 0.235639  [    0/ 8000 samples]
# Loss: 0.391289  [ 3200/ 8000 samples]
# Loss: 0.282477  [ 6400/ 8000 samples]
# Average loss: 0.4672
# Test loss: 0.474593
#
# Epoch 132
# -------------------------------
# Loss: 0.249130  [    0/ 8000 samples]
# Loss: 0.248412  [ 3200/ 8000 samples]
# Loss: 0.260127  [ 6400/ 8000 samples]
# Average loss: 0.4653
# Test loss: 0.543924
#
# Epoch 133
# -------------------------------
# Loss: 0.301735  [    0/ 8000 samples]
# Loss: 0.181691  [ 3200/ 8000 samples]
# Loss: 0.172651  [ 6400/ 8000 samples]
# Average loss: 0.4590
# Test loss: 0.451746
#
# Epoch 134
# -------------------------------
# Loss: 0.404784  [    0/ 8000 samples]
# Loss: 0.204112  [ 3200/ 8000 samples]
# Loss: 0.225060  [ 6400/ 8000 samples]
# Average loss: 0.4616
# Test loss: 0.462392
#
# Epoch 135
# -------------------------------
# Loss: 0.281346  [    0/ 8000 samples]
# Loss: 0.143452  [ 3200/ 8000 samples]
# Loss: 0.101946  [ 6400/ 8000 samples]
# Average loss: 0.4443
# Test loss: 0.407043
#
# Epoch 136
# -------------------------------
# Loss: 0.159544  [    0/ 8000 samples]
# Loss: 0.220706  [ 3200/ 8000 samples]
# Loss: 0.222428  [ 6400/ 8000 samples]
# Average loss: 0.4577
# Test loss: 0.503090
#
# Epoch 137
# -------------------------------
# Loss: 0.177419  [    0/ 8000 samples]
# Loss: 0.225875  [ 3200/ 8000 samples]
# Loss: 0.187781  [ 6400/ 8000 samples]
# Average loss: 0.4298
# Test loss: 0.391892
#
# Epoch 138
# -------------------------------
# Loss: 0.171984  [    0/ 8000 samples]
# Loss: 0.183282  [ 3200/ 8000 samples]
# Loss: 0.172845  [ 6400/ 8000 samples]
# Average loss: 0.4371
# Test loss: 0.442438
#
# Epoch 139
# -------------------------------
# Loss: 0.196130  [    0/ 8000 samples]
# Loss: 0.295482  [ 3200/ 8000 samples]
# Loss: 0.199996  [ 6400/ 8000 samples]
# Average loss: 0.4457
# Test loss: 0.431323
#
# Epoch 140
# -------------------------------
# Loss: 0.146903  [    0/ 8000 samples]
# Loss: 0.177605  [ 3200/ 8000 samples]
# Loss: 0.312440  [ 6400/ 8000 samples]
# Average loss: 0.4193
# Test loss: 0.430217
#
# Epoch 141
# -------------------------------
# Loss: 0.211265  [    0/ 8000 samples]
# Loss: 0.163775  [ 3200/ 8000 samples]
# Loss: 0.246227  [ 6400/ 8000 samples]
# Average loss: 0.4510
# Test loss: 0.429364
#
# Epoch 142
# -------------------------------
# Loss: 0.390525  [    0/ 8000 samples]
# Loss: 0.242812  [ 3200/ 8000 samples]
# Loss: 0.228318  [ 6400/ 8000 samples]
# Average loss: 0.4371
# Test loss: 0.479238
#
# Epoch 143
# -------------------------------
# Loss: 0.216796  [    0/ 8000 samples]
# Loss: 0.146873  [ 3200/ 8000 samples]
# Loss: 0.194232  [ 6400/ 8000 samples]
# Average loss: 0.4075
# Test loss: 0.394422
#
# Epoch 144
# -------------------------------
# Loss: 0.306582  [    0/ 8000 samples]
# Loss: 0.169901  [ 3200/ 8000 samples]
# Loss: 0.228633  [ 6400/ 8000 samples]
# Average loss: 0.4410
# Test loss: 0.419802
#
# Epoch 145
# -------------------------------
# Loss: 0.199700  [    0/ 8000 samples]
# Loss: 0.178017  [ 3200/ 8000 samples]
# Loss: 0.163857  [ 6400/ 8000 samples]
# Average loss: 0.4222
# Test loss: 0.433426
#
# Epoch 146
# -------------------------------
# Loss: 0.228430  [    0/ 8000 samples]
# Loss: 0.220174  [ 3200/ 8000 samples]
# Loss: 0.144800  [ 6400/ 8000 samples]
# Average loss: 0.4253
# Test loss: 0.430512
#
# Epoch 147
# -------------------------------
# Loss: 0.186824  [    0/ 8000 samples]
# Loss: 0.156925  [ 3200/ 8000 samples]
# Loss: 0.173070  [ 6400/ 8000 samples]
# Average loss: 0.4377
# Test loss: 0.441604
#
# Epoch 148
# -------------------------------
# Loss: 0.235200  [    0/ 8000 samples]
# Loss: 0.171013  [ 3200/ 8000 samples]
# Loss: 0.196305  [ 6400/ 8000 samples]
# Average loss: 0.4482
# Test loss: 0.477697
#
# Epoch 149
# -------------------------------
# Loss: 0.160853  [    0/ 8000 samples]
# Loss: 0.168709  [ 3200/ 8000 samples]
# Loss: 0.205459  [ 6400/ 8000 samples]
# Average loss: 0.4229
# Test loss: 0.435052
#
# Epoch 150
# -------------------------------
# Loss: 0.151848  [    0/ 8000 samples]
# Loss: 0.281466  [ 3200/ 8000 samples]
# Loss: 0.230544  [ 6400/ 8000 samples]
# Average loss: 0.4363
# Test loss: 0.505624
#
# Epoch 151
# -------------------------------
# Loss: 0.310919  [    0/ 8000 samples]
# Loss: 0.190772  [ 3200/ 8000 samples]
# Loss: 0.245135  [ 6400/ 8000 samples]
# Average loss: 0.4433
# Test loss: 0.424763
#
# Epoch 152
# -------------------------------
# Loss: 0.136438  [    0/ 8000 samples]
# Loss: 0.180911  [ 3200/ 8000 samples]
# Loss: 0.159261  [ 6400/ 8000 samples]
# Average loss: 0.4231
# Test loss: 0.485179
#
# Epoch 153
# -------------------------------
# Loss: 0.219553  [    0/ 8000 samples]
# Loss: 0.253429  [ 3200/ 8000 samples]
# Loss: 0.239622  [ 6400/ 8000 samples]
# Average loss: 0.4114
# Test loss: 0.359823
#
# Epoch 154
# -------------------------------
# Loss: 0.217500  [    0/ 8000 samples]
# Loss: 0.351722  [ 3200/ 8000 samples]
# Loss: 0.185979  [ 6400/ 8000 samples]
# Average loss: 0.4438
# Test loss: 0.423525
#
# Epoch 155
# -------------------------------
# Loss: 0.141517  [    0/ 8000 samples]
# Loss: 0.188043  [ 3200/ 8000 samples]
# Loss: 0.125092  [ 6400/ 8000 samples]
# Average loss: 0.4449
# Test loss: 0.448484
#
# Epoch 156
# -------------------------------
# Loss: 0.172427  [    0/ 8000 samples]
# Loss: 0.212479  [ 3200/ 8000 samples]
# Loss: 0.334579  [ 6400/ 8000 samples]
# Average loss: 0.4290
# Test loss: 0.400935
#
# Epoch 157
# -------------------------------
# Loss: 0.170613  [    0/ 8000 samples]
# Loss: 0.177999  [ 3200/ 8000 samples]
# Loss: 0.241847  [ 6400/ 8000 samples]
# Average loss: 0.4369
# Test loss: 0.438733
#
# Epoch 158
# -------------------------------
# Loss: 0.316881  [    0/ 8000 samples]
# Loss: 0.246005  [ 3200/ 8000 samples]
# Loss: 0.282757  [ 6400/ 8000 samples]
# Average loss: 0.4203
# Test loss: 0.405616
#
# Epoch 159
# -------------------------------
# Loss: 0.153751  [    0/ 8000 samples]
# Loss: 0.222245  [ 3200/ 8000 samples]
# Loss: 0.172786  [ 6400/ 8000 samples]
# Average loss: 0.4325
# Test loss: 0.501688
#
# Epoch 160
# -------------------------------
# Loss: 0.228421  [    0/ 8000 samples]
# Loss: 0.266038  [ 3200/ 8000 samples]
# Loss: 0.144408  [ 6400/ 8000 samples]
# Average loss: 0.4299
# Test loss: 0.404967
#
# Epoch 161
# -------------------------------
# Loss: 0.203877  [    0/ 8000 samples]
# Loss: 0.164901  [ 3200/ 8000 samples]
# Loss: 0.182577  [ 6400/ 8000 samples]
# Average loss: 0.4314
# Test loss: 0.414476
#
# Epoch 162
# -------------------------------
# Loss: 0.207959  [    0/ 8000 samples]
# Loss: 0.224941  [ 3200/ 8000 samples]
# Loss: 0.227446  [ 6400/ 8000 samples]
# Average loss: 0.4045
# Test loss: 0.434560
#
# Epoch 163
# -------------------------------
# Loss: 0.206150  [    0/ 8000 samples]
# Loss: 0.232487  [ 3200/ 8000 samples]
# Loss: 0.133235  [ 6400/ 8000 samples]
# Average loss: 0.4102
# Test loss: 0.437405
#
# Epoch 164
# -------------------------------
# Loss: 0.147543  [    0/ 8000 samples]
# Loss: 0.259226  [ 3200/ 8000 samples]
# Loss: 0.214209  [ 6400/ 8000 samples]
# Average loss: 0.4028
# Test loss: 0.487093
#
# Epoch 165
# -------------------------------
# Loss: 0.252852  [    0/ 8000 samples]
# Loss: 0.237872  [ 3200/ 8000 samples]
# Loss: 0.154348  [ 6400/ 8000 samples]
# Average loss: 0.4405
# Test loss: 0.392222
#
# Epoch 166
# -------------------------------
# Loss: 0.192193  [    0/ 8000 samples]
# Loss: 0.161121  [ 3200/ 8000 samples]
# Loss: 0.277320  [ 6400/ 8000 samples]
# Average loss: 0.4130
# Test loss: 0.385267
#
# Epoch 167
# -------------------------------
# Loss: 0.182954  [    0/ 8000 samples]
# Loss: 0.146333  [ 3200/ 8000 samples]
# Loss: 0.129126  [ 6400/ 8000 samples]
# Average loss: 0.4402
# Test loss: 0.414759
#
# Epoch 168
# -------------------------------
# Loss: 0.224208  [    0/ 8000 samples]
# Loss: 0.210060  [ 3200/ 8000 samples]
# Loss: 0.138844  [ 6400/ 8000 samples]
# Average loss: 0.4027
# Test loss: 0.436844
#
# Epoch 169
# -------------------------------
# Loss: 0.204549  [    0/ 8000 samples]
# Loss: 0.335862  [ 3200/ 8000 samples]
# Loss: 0.219693  [ 6400/ 8000 samples]
# Average loss: 0.4344
# Test loss: 0.445800
#
# Epoch 170
# -------------------------------
# Loss: 0.168256  [    0/ 8000 samples]
# Loss: 0.172474  [ 3200/ 8000 samples]
# Loss: 0.137378  [ 6400/ 8000 samples]
# Average loss: 0.4144
# Test loss: 0.390096
#
# Epoch 171
# -------------------------------
# Loss: 0.301579  [    0/ 8000 samples]
# Loss: 0.191523  [ 3200/ 8000 samples]
# Loss: 0.221570  [ 6400/ 8000 samples]
# Average loss: 0.4228
# Test loss: 0.392256
#
# Epoch 172
# -------------------------------
# Loss: 0.288453  [    0/ 8000 samples]
# Loss: 0.189794  [ 3200/ 8000 samples]
# Loss: 0.216715  [ 6400/ 8000 samples]
# Average loss: 0.3920
# Test loss: 0.401766
#
# Epoch 173
# -------------------------------
# Loss: 0.320142  [    0/ 8000 samples]
# Loss: 0.383621  [ 3200/ 8000 samples]
# Loss: 0.180408  [ 6400/ 8000 samples]
# Average loss: 0.4009
# Test loss: 0.444577
#
# Epoch 174
# -------------------------------
# Loss: 0.303170  [    0/ 8000 samples]
# Loss: 0.107921  [ 3200/ 8000 samples]
# Loss: 0.211325  [ 6400/ 8000 samples]
# Average loss: 0.4047
# Test loss: 0.380540
#
# Epoch 175
# -------------------------------
# Loss: 0.258503  [    0/ 8000 samples]
# Loss: 0.146933  [ 3200/ 8000 samples]
# Loss: 0.302468  [ 6400/ 8000 samples]
# Average loss: 0.3995
# Test loss: 0.435557
#
# Epoch 176
# -------------------------------
# Loss: 0.168082  [    0/ 8000 samples]
# Loss: 0.209996  [ 3200/ 8000 samples]
# Loss: 0.210262  [ 6400/ 8000 samples]
# Average loss: 0.4654
# Test loss: 0.404018
#
# Epoch 177
# -------------------------------
# Loss: 0.173596  [    0/ 8000 samples]
# Loss: 0.251402  [ 3200/ 8000 samples]
# Loss: 0.201582  [ 6400/ 8000 samples]
# Average loss: 0.4218
# Test loss: 0.540638
#
# Epoch 178
# -------------------------------
# Loss: 0.221995  [    0/ 8000 samples]
# Loss: 0.171159  [ 3200/ 8000 samples]
# Loss: 0.215800  [ 6400/ 8000 samples]
# Average loss: 0.4333
# Test loss: 0.405294
#
# Epoch 179
# -------------------------------
# Loss: 0.208958  [    0/ 8000 samples]
# Loss: 0.171608  [ 3200/ 8000 samples]
# Loss: 0.210566  [ 6400/ 8000 samples]
# Average loss: 0.4213
# Test loss: 0.354670
#
# Epoch 180
# -------------------------------
# Loss: 0.160728  [    0/ 8000 samples]
# Loss: 0.113301  [ 3200/ 8000 samples]
# Loss: 0.240401  [ 6400/ 8000 samples]
# Average loss: 0.3866
# Test loss: 0.432139
#
# Epoch 181
# -------------------------------
# Loss: 0.325416  [    0/ 8000 samples]
# Loss: 0.217286  [ 3200/ 8000 samples]
# Loss: 0.134527  [ 6400/ 8000 samples]
# Average loss: 0.4205
# Test loss: 0.433514
#
# Epoch 182
# -------------------------------
# Loss: 0.150160  [    0/ 8000 samples]
# Loss: 0.207567  [ 3200/ 8000 samples]
# Loss: 0.226868  [ 6400/ 8000 samples]
# Average loss: 0.4577
# Test loss: 0.400957
#
# Epoch 183
# -------------------------------
# Loss: 0.241373  [    0/ 8000 samples]
# Loss: 0.154877  [ 3200/ 8000 samples]
# Loss: 0.191749  [ 6400/ 8000 samples]
# Average loss: 0.4101
# Test loss: 0.398853
#
# Epoch 184
# -------------------------------
# Loss: 0.136380  [    0/ 8000 samples]
# Loss: 0.242338  [ 3200/ 8000 samples]
# Loss: 0.147291  [ 6400/ 8000 samples]
# Average loss: 0.4197
# Test loss: 0.390243
#
# Epoch 185
# -------------------------------
# Loss: 0.249794  [    0/ 8000 samples]
# Loss: 0.151749  [ 3200/ 8000 samples]
# Loss: 0.193897  [ 6400/ 8000 samples]
# Average loss: 0.4263
# Test loss: 0.380611
#
# Epoch 186
# -------------------------------
# Loss: 0.217523  [    0/ 8000 samples]
# Loss: 0.145406  [ 3200/ 8000 samples]
# Loss: 0.265415  [ 6400/ 8000 samples]
# Average loss: 0.3935
# Test loss: 0.394281
#
# Epoch 187
# -------------------------------
# Loss: 0.261557  [    0/ 8000 samples]
# Loss: 0.246233  [ 3200/ 8000 samples]
# Loss: 0.285837  [ 6400/ 8000 samples]
# Average loss: 0.4035
# Test loss: 0.419571
#
# Epoch 188
# -------------------------------
# Loss: 0.302232  [    0/ 8000 samples]
# Loss: 0.194337  [ 3200/ 8000 samples]
# Loss: 0.114447  [ 6400/ 8000 samples]
# Average loss: 0.3738
# Test loss: 0.386918
#
# Epoch 189
# -------------------------------
# Loss: 0.300062  [    0/ 8000 samples]
# Loss: 0.140520  [ 3200/ 8000 samples]
# Loss: 0.313831  [ 6400/ 8000 samples]
# Average loss: 0.4049
# Test loss: 0.373884
#
# Epoch 190
# -------------------------------
# Loss: 0.220791  [    0/ 8000 samples]
# Loss: 0.315814  [ 3200/ 8000 samples]
# Loss: 0.226503  [ 6400/ 8000 samples]
# Average loss: 0.3769
# Test loss: 0.401341
#
# Epoch 191
# -------------------------------
# Loss: 0.122393  [    0/ 8000 samples]
# Loss: 0.230918  [ 3200/ 8000 samples]
# Loss: 0.126265  [ 6400/ 8000 samples]
# Average loss: 0.4009
# Test loss: 0.327313
#
# Epoch 192
# -------------------------------
# Loss: 0.141422  [    0/ 8000 samples]
# Loss: 0.205999  [ 3200/ 8000 samples]
# Loss: 0.210880  [ 6400/ 8000 samples]
# Average loss: 0.4139
# Test loss: 0.376416
#
# Epoch 193
# -------------------------------
# Loss: 0.318756  [    0/ 8000 samples]
# Loss: 0.216895  [ 3200/ 8000 samples]
# Loss: 0.298270  [ 6400/ 8000 samples]
# Average loss: 0.4015
# Test loss: 0.415193
#
# Epoch 194
# -------------------------------
# Loss: 0.194389  [    0/ 8000 samples]
# Loss: 0.140933  [ 3200/ 8000 samples]
# Loss: 0.186324  [ 6400/ 8000 samples]
# Average loss: 0.4136
# Test loss: 0.383085
#
# Epoch 195
# -------------------------------
# Loss: 0.137992  [    0/ 8000 samples]
# Loss: 0.197178  [ 3200/ 8000 samples]
# Loss: 0.175714  [ 6400/ 8000 samples]
# Average loss: 0.3862
# Test loss: 0.430497
#
# Epoch 196
# -------------------------------
# Loss: 0.181364  [    0/ 8000 samples]
# Loss: 0.281640  [ 3200/ 8000 samples]
# Loss: 0.178100  [ 6400/ 8000 samples]
# Average loss: 0.3964
# Test loss: 0.408292
#
# Epoch 197
# -------------------------------
# Loss: 0.154799  [    0/ 8000 samples]
# Loss: 0.223062  [ 3200/ 8000 samples]
# Loss: 0.154885  [ 6400/ 8000 samples]
# Average loss: 0.4228
# Test loss: 0.387677
#
# Epoch 198
# -------------------------------
# Loss: 0.199004  [    0/ 8000 samples]
# Loss: 0.251774  [ 3200/ 8000 samples]
# Loss: 0.262498  [ 6400/ 8000 samples]
# Average loss: 0.4051
# Test loss: 0.379744
#
# Epoch 199
# -------------------------------
# Loss: 0.152672  [    0/ 8000 samples]
# Loss: 0.200658  [ 3200/ 8000 samples]
# Loss: 0.202926  [ 6400/ 8000 samples]
# Average loss: 0.3977
# Test loss: 0.369406
#
# Epoch 200
# -------------------------------
# Loss: 0.185010  [    0/ 8000 samples]
# Loss: 0.190605  [ 3200/ 8000 samples]
# Loss: 0.156489  [ 6400/ 8000 samples]
# Average loss: 0.4099
# Test loss: 0.376600
#
# Epoch 201
# -------------------------------
# Loss: 0.237132  [    0/ 8000 samples]
# Loss: 0.230821  [ 3200/ 8000 samples]
# Loss: 0.185044  [ 6400/ 8000 samples]
# Average loss: 0.3844
# Test loss: 0.387877
#
# Epoch 202
# -------------------------------
# Loss: 0.243541  [    0/ 8000 samples]
# Loss: 0.158322  [ 3200/ 8000 samples]
# Loss: 0.216338  [ 6400/ 8000 samples]
# Average loss: 0.3977
# Test loss: 0.427896
#
# Epoch 203
# -------------------------------
# Loss: 0.256799  [    0/ 8000 samples]
# Loss: 0.174244  [ 3200/ 8000 samples]
# Loss: 0.250802  [ 6400/ 8000 samples]
# Average loss: 0.3836
# Test loss: 0.357016
#
# Epoch 204
# -------------------------------
# Loss: 0.180218  [    0/ 8000 samples]
# Loss: 0.137832  [ 3200/ 8000 samples]
# Loss: 0.190104  [ 6400/ 8000 samples]
# Average loss: 0.4102
# Test loss: 0.342931
#
# Epoch 205
# -------------------------------
# Loss: 0.174888  [    0/ 8000 samples]
# Loss: 0.196411  [ 3200/ 8000 samples]
# Loss: 0.141832  [ 6400/ 8000 samples]
# Average loss: 0.3856
# Test loss: 0.420438
#
# Epoch 206
# -------------------------------
# Loss: 0.159626  [    0/ 8000 samples]
# Loss: 0.171159  [ 3200/ 8000 samples]
# Loss: 0.217534  [ 6400/ 8000 samples]
# Average loss: 0.4037
# Test loss: 0.368078
#
# Epoch 207
# -------------------------------
# Loss: 0.127764  [    0/ 8000 samples]
# Loss: 0.200552  [ 3200/ 8000 samples]
# Loss: 0.188368  [ 6400/ 8000 samples]
# Average loss: 0.3909
# Test loss: 0.367656
#
# Epoch 208
# -------------------------------
# Loss: 0.218825  [    0/ 8000 samples]
# Loss: 0.148653  [ 3200/ 8000 samples]
# Loss: 0.134517  [ 6400/ 8000 samples]
# Average loss: 0.3996
# Test loss: 0.355273
#
# Epoch 209
# -------------------------------
# Loss: 0.145763  [    0/ 8000 samples]
# Loss: 0.189754  [ 3200/ 8000 samples]
# Loss: 0.174049  [ 6400/ 8000 samples]
# Average loss: 0.3719
# Test loss: 0.346532
#
# Epoch 210
# -------------------------------
# Loss: 0.186778  [    0/ 8000 samples]
# Loss: 0.178585  [ 3200/ 8000 samples]
# Loss: 0.216686  [ 6400/ 8000 samples]
# Average loss: 0.3973
# Test loss: 0.379074
#
# Epoch 211
# -------------------------------
# Loss: 0.231543  [    0/ 8000 samples]
# Loss: 0.132831  [ 3200/ 8000 samples]
# Loss: 0.266133  [ 6400/ 8000 samples]
# Average loss: 0.3952
# Test loss: 0.446464
#
# Epoch 212
# -------------------------------
# Loss: 0.103115  [    0/ 8000 samples]
# Loss: 0.258611  [ 3200/ 8000 samples]
# Loss: 0.195568  [ 6400/ 8000 samples]
# Average loss: 0.4134
# Test loss: 0.366768
#
# Epoch 213
# -------------------------------
# Loss: 0.227434  [    0/ 8000 samples]
# Loss: 0.181437  [ 3200/ 8000 samples]
# Loss: 0.126905  [ 6400/ 8000 samples]
# Average loss: 0.3814
# Test loss: 0.403041
#
# Epoch 214
# -------------------------------
# Loss: 0.136694  [    0/ 8000 samples]
# Loss: 0.207361  [ 3200/ 8000 samples]
# Loss: 0.149106  [ 6400/ 8000 samples]
# Average loss: 0.3755
# Test loss: 0.384156
#
# Epoch 215
# -------------------------------
# Loss: 0.129085  [    0/ 8000 samples]
# Loss: 0.280306  [ 3200/ 8000 samples]
# Loss: 0.235583  [ 6400/ 8000 samples]
# Average loss: 0.4056
# Test loss: 0.351783
#
# Epoch 216
# -------------------------------
# Loss: 0.204882  [    0/ 8000 samples]
# Loss: 0.216228  [ 3200/ 8000 samples]
# Loss: 0.243339  [ 6400/ 8000 samples]
# Average loss: 0.3793
# Test loss: 0.338268
#
# Epoch 217
# -------------------------------
# Loss: 0.165259  [    0/ 8000 samples]
# Loss: 0.109300  [ 3200/ 8000 samples]
# Loss: 0.318836  [ 6400/ 8000 samples]
# Average loss: 0.3766
# Test loss: 0.399658
#
# Epoch 218
# -------------------------------
# Loss: 0.246657  [    0/ 8000 samples]
# Loss: 0.206253  [ 3200/ 8000 samples]
# Loss: 0.134315  [ 6400/ 8000 samples]
# Average loss: 0.3932
# Test loss: 0.400495
#
# Epoch 219
# -------------------------------
# Loss: 0.155065  [    0/ 8000 samples]
# Loss: 0.195810  [ 3200/ 8000 samples]
# Loss: 0.150979  [ 6400/ 8000 samples]
# Average loss: 0.4187
# Test loss: 0.445520
#
# Epoch 220
# -------------------------------
# Loss: 0.167635  [    0/ 8000 samples]
# Loss: 0.156528  [ 3200/ 8000 samples]
# Loss: 0.213121  [ 6400/ 8000 samples]
# Average loss: 0.3730
# Test loss: 0.410085
#
# Epoch 221
# -------------------------------
# Loss: 0.161574  [    0/ 8000 samples]
# Loss: 0.135544  [ 3200/ 8000 samples]
# Loss: 0.119234  [ 6400/ 8000 samples]
# Average loss: 0.3970
# Test loss: 0.427195
#
# Epoch 222
# -------------------------------
# Loss: 0.086864  [    0/ 8000 samples]
# Loss: 0.121940  [ 3200/ 8000 samples]
# Loss: 0.182298  [ 6400/ 8000 samples]
# Average loss: 0.3864
# Test loss: 0.360276
#
# Epoch 223
# -------------------------------
# Loss: 0.109583  [    0/ 8000 samples]
# Loss: 0.182281  [ 3200/ 8000 samples]
# Loss: 0.403251  [ 6400/ 8000 samples]
# Average loss: 0.3887
# Test loss: 0.412262
#
# Epoch 224
# -------------------------------
# Loss: 0.183268  [    0/ 8000 samples]
# Loss: 0.192301  [ 3200/ 8000 samples]
# Loss: 0.171725  [ 6400/ 8000 samples]
# Average loss: 0.3746
# Test loss: 0.363289
#
# Epoch 225
# -------------------------------
# Loss: 0.186746  [    0/ 8000 samples]
# Loss: 0.158759  [ 3200/ 8000 samples]
# Loss: 0.181042  [ 6400/ 8000 samples]
# Average loss: 0.3830
# Test loss: 0.364664
#
# Epoch 226
# -------------------------------
# Loss: 0.142367  [    0/ 8000 samples]
# Loss: 0.181657  [ 3200/ 8000 samples]
# Loss: 0.177844  [ 6400/ 8000 samples]
# Average loss: 0.3524
# Test loss: 0.357281
#
# Epoch 227
# -------------------------------
# Loss: 0.314451  [    0/ 8000 samples]
# Loss: 0.260772  [ 3200/ 8000 samples]
# Loss: 0.166578  [ 6400/ 8000 samples]
# Average loss: 0.3955
# Test loss: 0.343941
#
# Epoch 228
# -------------------------------
# Loss: 0.211471  [    0/ 8000 samples]
# Loss: 0.115499  [ 3200/ 8000 samples]
# Loss: 0.286833  [ 6400/ 8000 samples]
# Average loss: 0.3809
# Test loss: 0.368128
#
# Epoch 229
# -------------------------------
# Loss: 0.215133  [    0/ 8000 samples]
# Loss: 0.156040  [ 3200/ 8000 samples]
# Loss: 0.133344  [ 6400/ 8000 samples]
# Average loss: 0.3535
# Test loss: 0.419892
#
# Epoch 230
# -------------------------------
# Loss: 0.142245  [    0/ 8000 samples]
# Loss: 0.128531  [ 3200/ 8000 samples]
# Loss: 0.303607  [ 6400/ 8000 samples]
# Average loss: 0.3901
# Test loss: 0.389001
#
# Epoch 231
# -------------------------------
# Loss: 0.107717  [    0/ 8000 samples]
# Loss: 0.190998  [ 3200/ 8000 samples]
# Loss: 0.300871  [ 6400/ 8000 samples]
# Average loss: 0.3701
# Test loss: 0.359867
#
# Epoch 232
# -------------------------------
# Loss: 0.175775  [    0/ 8000 samples]
# Loss: 0.150817  [ 3200/ 8000 samples]
# Loss: 0.205263  [ 6400/ 8000 samples]
# Average loss: 0.3842
# Test loss: 0.399771
#
# Epoch 233
# -------------------------------
# Loss: 0.216907  [    0/ 8000 samples]
# Loss: 0.176249  [ 3200/ 8000 samples]
# Loss: 0.164591  [ 6400/ 8000 samples]
# Average loss: 0.3826
# Test loss: 0.315968
#
# Epoch 234
# -------------------------------
# Loss: 0.246874  [    0/ 8000 samples]
# Loss: 0.142773  [ 3200/ 8000 samples]
# Loss: 0.193198  [ 6400/ 8000 samples]
# Average loss: 0.3675
# Test loss: 0.380950
#
# Epoch 235
# -------------------------------
# Loss: 0.251462  [    0/ 8000 samples]
# Loss: 0.243535  [ 3200/ 8000 samples]
# Loss: 0.171181  [ 6400/ 8000 samples]
# Average loss: 0.3893
# Test loss: 0.385750
#
# Epoch 236
# -------------------------------
# Loss: 0.183739  [    0/ 8000 samples]
# Loss: 0.150559  [ 3200/ 8000 samples]
# Loss: 0.148084  [ 6400/ 8000 samples]
# Average loss: 0.3698
# Test loss: 0.319310
#
# Epoch 237
# -------------------------------
# Loss: 0.140233  [    0/ 8000 samples]
# Loss: 0.252467  [ 3200/ 8000 samples]
# Loss: 0.187168  [ 6400/ 8000 samples]
# Average loss: 0.3582
# Test loss: 0.350236
#
# Epoch 238
# -------------------------------
# Loss: 0.158762  [    0/ 8000 samples]
# Loss: 0.138665  [ 3200/ 8000 samples]
# Loss: 0.255870  [ 6400/ 8000 samples]
# Average loss: 0.3696
# Test loss: 0.356336
#
# Epoch 239
# -------------------------------
# Loss: 0.200027  [    0/ 8000 samples]
# Loss: 0.299715  [ 3200/ 8000 samples]
# Loss: 0.133174  [ 6400/ 8000 samples]
# Average loss: 0.3821
# Test loss: 0.389213
#
# Epoch 240
# -------------------------------
# Loss: 0.265822  [    0/ 8000 samples]
# Loss: 0.149684  [ 3200/ 8000 samples]
# Loss: 0.158700  [ 6400/ 8000 samples]
# Average loss: 0.3740
# Test loss: 0.400538
#
# Epoch 241
# -------------------------------
# Loss: 0.189830  [    0/ 8000 samples]
# Loss: 0.132388  [ 3200/ 8000 samples]
# Loss: 0.175834  [ 6400/ 8000 samples]
# Average loss: 0.4071
# Test loss: 0.344844
#
# Epoch 242
# -------------------------------
# Loss: 0.330057  [    0/ 8000 samples]
# Loss: 0.270148  [ 3200/ 8000 samples]
# ...
# Average loss: 0.3315
# Test loss: 0.348998
#
# Epoch 421
# -------------------------------
# Loss: 0.132347  [    0/ 8000 samples]
# Loss: 0.142305  [ 3200/ 8000 samples]
# Loss: 0.145899  [ 6400/ 8000 samples]
# Average loss: 0.3122
# Test loss: 0.335263
#
# Epoch 422
# -------------------------------
# Loss: 0.145199  [    0/ 8000 samples]
# Loss: 0.109419  [ 3200/ 8000 samples]
# Loss: 0.239821  [ 6400/ 8000 samples]
# Average loss: 0.3285
# Test loss: 0.303244
#
# Epoch 423
# -------------------------------
# Loss: 0.132804  [    0/ 8000 samples]
# Loss: 0.123435  [ 3200/ 8000 samples]
# Loss: 0.120232  [ 6400/ 8000 samples]
# Average loss: 0.3254
# Test loss: 0.325826
#
# Epoch 424
# -------------------------------
# Loss: 0.206192  [    0/ 8000 samples]
# Loss: 0.079141  [ 3200/ 8000 samples]
# Loss: 0.118822  [ 6400/ 8000 samples]
# Average loss: 0.2991
# Test loss: 0.306799
#
# Epoch 425
# -------------------------------
# Loss: 0.241483  [    0/ 8000 samples]
# Loss: 0.193407  [ 3200/ 8000 samples]
# Loss: 0.148485  [ 6400/ 8000 samples]
# Average loss: 0.3483
# Test loss: 0.358930
#
# Epoch 426
# -------------------------------
# Loss: 0.258183  [    0/ 8000 samples]
# Loss: 0.154115  [ 3200/ 8000 samples]
# Loss: 0.162018  [ 6400/ 8000 samples]
# Average loss: 0.3335
# Test loss: 0.289889
#
# Epoch 427
# -------------------------------
# Loss: 0.132392  [    0/ 8000 samples]
# Loss: 0.143256  [ 3200/ 8000 samples]
# Loss: 0.127003  [ 6400/ 8000 samples]
# Average loss: 0.3164
# Test loss: 0.339394
#
# Epoch 428
# -------------------------------
# Loss: 0.106962  [    0/ 8000 samples]
# Loss: 0.222886  [ 3200/ 8000 samples]
# Loss: 0.123163  [ 6400/ 8000 samples]
# Average loss: 0.3272
# Test loss: 0.316290
#
# Epoch 429
# -------------------------------
# Loss: 0.118676  [    0/ 8000 samples]
# Loss: 0.142872  [ 3200/ 8000 samples]
# Loss: 0.134344  [ 6400/ 8000 samples]
# Average loss: 0.3055
# Test loss: 0.279196
#
# Epoch 430
# -------------------------------
# Loss: 0.161040  [    0/ 8000 samples]
# Loss: 0.103255  [ 3200/ 8000 samples]
# Loss: 0.102385  [ 6400/ 8000 samples]
# Average loss: 0.3164
# Test loss: 0.320641
#
# Epoch 431
# -------------------------------
# Loss: 0.211819  [    0/ 8000 samples]
# Loss: 0.214394  [ 3200/ 8000 samples]
# Loss: 0.180045  [ 6400/ 8000 samples]
# Average loss: 0.3136
# Test loss: 0.325714
#
# Epoch 432
# -------------------------------
# Loss: 0.185151  [    0/ 8000 samples]
# Loss: 0.134328  [ 3200/ 8000 samples]
# Loss: 0.250354  [ 6400/ 8000 samples]
# Average loss: 0.3169
# Test loss: 0.359367
#
# Epoch 433
# -------------------------------
# Loss: 0.167897  [    0/ 8000 samples]
# Loss: 0.181073  [ 3200/ 8000 samples]
# Loss: 0.104474  [ 6400/ 8000 samples]
# Average loss: 0.3175
# Test loss: 0.289919
#
# Epoch 434
# -------------------------------
# Loss: 0.121770  [    0/ 8000 samples]
# Loss: 0.193673  [ 3200/ 8000 samples]
# Loss: 0.144436  [ 6400/ 8000 samples]
# Average loss: 0.3205
# Test loss: 0.303653
#
# Epoch 435
# -------------------------------
# Loss: 0.152425  [    0/ 8000 samples]
# Loss: 0.237720  [ 3200/ 8000 samples]
# Loss: 0.169773  [ 6400/ 8000 samples]
# Average loss: 0.3241
# Test loss: 0.303760
#
# Epoch 436
# -------------------------------
# Loss: 0.165206  [    0/ 8000 samples]
# Loss: 0.156753  [ 3200/ 8000 samples]
# Loss: 0.198294  [ 6400/ 8000 samples]
# Average loss: 0.3107
# Test loss: 0.331211
#
# Epoch 437
# -------------------------------
# Loss: 0.113096  [    0/ 8000 samples]
# Loss: 0.146773  [ 3200/ 8000 samples]
# Loss: 0.205756  [ 6400/ 8000 samples]
# Average loss: 0.3265
# Test loss: 0.342413
#
# Epoch 438
# -------------------------------
# Loss: 0.132529  [    0/ 8000 samples]
# Loss: 0.158132  [ 3200/ 8000 samples]
# Loss: 0.238623  [ 6400/ 8000 samples]
# Average loss: 0.3286
# Test loss: 0.321907
#
# Epoch 439
# -------------------------------
# Loss: 0.200702  [    0/ 8000 samples]
# Loss: 0.236760  [ 3200/ 8000 samples]
# Loss: 0.107948  [ 6400/ 8000 samples]
# Average loss: 0.3020
# Test loss: 0.292520
#
# Epoch 440
# -------------------------------
# Loss: 0.188129  [    0/ 8000 samples]
# Loss: 0.145635  [ 3200/ 8000 samples]
# Loss: 0.146507  [ 6400/ 8000 samples]
# Average loss: 0.3092
# Test loss: 0.274012
#
# Epoch 441
# -------------------------------
# Loss: 0.167967  [    0/ 8000 samples]
# Loss: 0.116575  [ 3200/ 8000 samples]
# Loss: 0.121457  [ 6400/ 8000 samples]
# Average loss: 0.3108
# Test loss: 0.346078
#
# Epoch 442
# -------------------------------
# Loss: 0.183865  [    0/ 8000 samples]
# Loss: 0.149055  [ 3200/ 8000 samples]
# Loss: 0.153129  [ 6400/ 8000 samples]
# Average loss: 0.3438
# Test loss: 0.301371
#
# Epoch 443
# -------------------------------
# Loss: 0.081952  [    0/ 8000 samples]
# Loss: 0.112460  [ 3200/ 8000 samples]
# Loss: 0.151489  [ 6400/ 8000 samples]
# Average loss: 0.3503
# Test loss: 0.420226
#
# Epoch 444
# -------------------------------
# Loss: 0.260782  [    0/ 8000 samples]
# Loss: 0.120669  [ 3200/ 8000 samples]
# Loss: 0.153875  [ 6400/ 8000 samples]
# Average loss: 0.3199
# Test loss: 0.323312
#
# Epoch 445
# -------------------------------
# Loss: 0.160903  [    0/ 8000 samples]
# Loss: 0.356404  [ 3200/ 8000 samples]
# Loss: 0.164030  [ 6400/ 8000 samples]
# Average loss: 0.3248
# Test loss: 0.330631
#
# Epoch 446
# -------------------------------
# Loss: 0.134066  [    0/ 8000 samples]
# Loss: 0.200038  [ 3200/ 8000 samples]
# Loss: 0.116074  [ 6400/ 8000 samples]
# Average loss: 0.3321
# Test loss: 0.325148
#
# Epoch 447
# -------------------------------
# Loss: 0.259010  [    0/ 8000 samples]
# Loss: 0.097646  [ 3200/ 8000 samples]
# Loss: 0.175253  [ 6400/ 8000 samples]
# Average loss: 0.3332
# Test loss: 0.283215
#
# Epoch 448
# -------------------------------
# Loss: 0.183364  [    0/ 8000 samples]
# Loss: 0.132329  [ 3200/ 8000 samples]
# Loss: 0.071308  [ 6400/ 8000 samples]
# Average loss: 0.3059
# Test loss: 0.335671
#
# Epoch 449
# -------------------------------
# Loss: 0.263265  [    0/ 8000 samples]
# Loss: 0.180781  [ 3200/ 8000 samples]
# Loss: 0.138148  [ 6400/ 8000 samples]
# Average loss: 0.3271
# Test loss: 0.330366
#
# Epoch 450
# -------------------------------
# Loss: 0.092869  [    0/ 8000 samples]
# Loss: 0.124631  [ 3200/ 8000 samples]
# Loss: 0.222830  [ 6400/ 8000 samples]
# Average loss: 0.3074
# Test loss: 0.296127
#
# Epoch 451
# -------------------------------
# Loss: 0.186077  [    0/ 8000 samples]
# Loss: 0.240390  [ 3200/ 8000 samples]
# Loss: 0.185985  [ 6400/ 8000 samples]
# Average loss: 0.3315
# Test loss: 0.290522
#
# Epoch 452
# -------------------------------
# Loss: 0.241621  [    0/ 8000 samples]
# Loss: 0.080634  [ 3200/ 8000 samples]
# Loss: 0.180296  [ 6400/ 8000 samples]
# Average loss: 0.3292
# Test loss: 0.334918
#
# Epoch 453
# -------------------------------
# Loss: 0.241987  [    0/ 8000 samples]
# Loss: 0.202158  [ 3200/ 8000 samples]
# Loss: 0.127235  [ 6400/ 8000 samples]
# Average loss: 0.3154
# Test loss: 0.333895
#
# Epoch 454
# -------------------------------
# Loss: 0.176275  [    0/ 8000 samples]
# Loss: 0.175881  [ 3200/ 8000 samples]
# Loss: 0.156651  [ 6400/ 8000 samples]
# Average loss: 0.3150
# Test loss: 0.324244
#
# Epoch 455
# -------------------------------
# Loss: 0.165872  [    0/ 8000 samples]
# Loss: 0.298948  [ 3200/ 8000 samples]
# Loss: 0.172943  [ 6400/ 8000 samples]
# Average loss: 0.3151
# Test loss: 0.314408
#
# Epoch 456
# -------------------------------
# Loss: 0.078065  [    0/ 8000 samples]
# Loss: 0.134751  [ 3200/ 8000 samples]
# Loss: 0.170842  [ 6400/ 8000 samples]
# Average loss: 0.2988
# Test loss: 0.281332
#
# Epoch 457
# -------------------------------
# Loss: 0.372827  [    0/ 8000 samples]
# Loss: 0.202832  [ 3200/ 8000 samples]
# Loss: 0.132125  [ 6400/ 8000 samples]
# Average loss: 0.3163
# Test loss: 0.324685
#
# Epoch 458
# -------------------------------
# Loss: 0.128703  [    0/ 8000 samples]
# Loss: 0.134537  [ 3200/ 8000 samples]
# Loss: 0.135694  [ 6400/ 8000 samples]
# Average loss: 0.3126
# Test loss: 0.298133
#
# Epoch 459
# -------------------------------
# Loss: 0.126332  [    0/ 8000 samples]
# Loss: 0.141418  [ 3200/ 8000 samples]
# Loss: 0.172652  [ 6400/ 8000 samples]
# Average loss: 0.3454
# Test loss: 0.332592
#
# Epoch 460
# -------------------------------
# Loss: 0.263224  [    0/ 8000 samples]
# Loss: 0.182691  [ 3200/ 8000 samples]
# Loss: 0.261152  [ 6400/ 8000 samples]
# Average loss: 0.3120
# Test loss: 0.367977
#
# Epoch 461
# -------------------------------
# Loss: 0.188300  [    0/ 8000 samples]
# Loss: 0.085811  [ 3200/ 8000 samples]
# Loss: 0.202360  [ 6400/ 8000 samples]
# Average loss: 0.3472
# Test loss: 0.326052
#
# Epoch 462
# -------------------------------
# Loss: 0.082809  [    0/ 8000 samples]
# Loss: 0.170773  [ 3200/ 8000 samples]
# Loss: 0.179615  [ 6400/ 8000 samples]
# Average loss: 0.3161
# Test loss: 0.342942
#
# Epoch 463
# -------------------------------
# Loss: 0.163929  [    0/ 8000 samples]
# Loss: 0.164490  [ 3200/ 8000 samples]
# Loss: 0.164559  [ 6400/ 8000 samples]
# Average loss: 0.3318
# Test loss: 0.301004
#
# Epoch 464
# -------------------------------
# Loss: 0.123130  [    0/ 8000 samples]
# Loss: 0.080573  [ 3200/ 8000 samples]
# Loss: 0.089245  [ 6400/ 8000 samples]
# Average loss: 0.2840
# Test loss: 0.314027
#
# Epoch 465
# -------------------------------
# Loss: 0.170561  [    0/ 8000 samples]
# Loss: 0.152455  [ 3200/ 8000 samples]
# Loss: 0.109568  [ 6400/ 8000 samples]
# Average loss: 0.3014
# Test loss: 0.313330
#
# Epoch 466
# -------------------------------
# Loss: 0.103177  [    0/ 8000 samples]
# Loss: 0.139019  [ 3200/ 8000 samples]
# Loss: 0.111429  [ 6400/ 8000 samples]
# Average loss: 0.3067
# Test loss: 0.324098
#
# Epoch 467
# -------------------------------
# Loss: 0.179336  [    0/ 8000 samples]
# Loss: 0.183911  [ 3200/ 8000 samples]
# Loss: 0.165406  [ 6400/ 8000 samples]
# Average loss: 0.3167
# Test loss: 0.302137
#
# Epoch 468
# -------------------------------
# Loss: 0.079831  [    0/ 8000 samples]
# Loss: 0.225141  [ 3200/ 8000 samples]
# Loss: 0.192841  [ 6400/ 8000 samples]
# Average loss: 0.3182
# Test loss: 0.281830
#
# Epoch 469
# -------------------------------
# Loss: 0.138385  [    0/ 8000 samples]
# Loss: 0.106297  [ 3200/ 8000 samples]
# Loss: 0.231326  [ 6400/ 8000 samples]
# Average loss: 0.3331
# Test loss: 0.281120
#
# Epoch 470
# -------------------------------
# Loss: 0.219787  [    0/ 8000 samples]
# Loss: 0.193649  [ 3200/ 8000 samples]
# Loss: 0.123048  [ 6400/ 8000 samples]
# Average loss: 0.3098
# Test loss: 0.296393
#
# Epoch 471
# -------------------------------
# Loss: 0.178667  [    0/ 8000 samples]
# Loss: 0.175333  [ 3200/ 8000 samples]
# Loss: 0.151943  [ 6400/ 8000 samples]
# Average loss: 0.3367
# Test loss: 0.302001
#
# Epoch 472
# -------------------------------
# Loss: 0.217761  [    0/ 8000 samples]
# Loss: 0.090227  [ 3200/ 8000 samples]
# Loss: 0.235071  [ 6400/ 8000 samples]
# Average loss: 0.3156
# Test loss: 0.348088
#
# Epoch 473
# -------------------------------
# Loss: 0.114385  [    0/ 8000 samples]
# Loss: 0.089494  [ 3200/ 8000 samples]
# Loss: 0.198291  [ 6400/ 8000 samples]
# Average loss: 0.3117
# Test loss: 0.341282
#
# Epoch 474
# -------------------------------
# Loss: 0.127612  [    0/ 8000 samples]
# Loss: 0.153832  [ 3200/ 8000 samples]
# Loss: 0.212203  [ 6400/ 8000 samples]
# Average loss: 0.3319
# Test loss: 0.318248
#
# Epoch 475
# -------------------------------
# Loss: 0.112600  [    0/ 8000 samples]
# Loss: 0.133450  [ 3200/ 8000 samples]
# Loss: 0.110964  [ 6400/ 8000 samples]
# Average loss: 0.3084
# Test loss: 0.279168
#
# Epoch 476
# -------------------------------
# Loss: 0.087513  [    0/ 8000 samples]
# Loss: 0.146453  [ 3200/ 8000 samples]
# Loss: 0.158043  [ 6400/ 8000 samples]
# Average loss: 0.3351
# Test loss: 0.305600
#
# Epoch 477
# -------------------------------
# Loss: 0.223916  [    0/ 8000 samples]
# Loss: 0.187533  [ 3200/ 8000 samples]
# Loss: 0.101951  [ 6400/ 8000 samples]
# Average loss: 0.2991
# Test loss: 0.283522
#
# Epoch 478
# -------------------------------
# Loss: 0.182630  [    0/ 8000 samples]
# Loss: 0.250908  [ 3200/ 8000 samples]
# Loss: 0.087975  [ 6400/ 8000 samples]
# Average loss: 0.2932
# Test loss: 0.310138
#
# Epoch 479
# -------------------------------
# Loss: 0.151773  [    0/ 8000 samples]
# Loss: 0.128588  [ 3200/ 8000 samples]
# Loss: 0.105609  [ 6400/ 8000 samples]
# Average loss: 0.3081
# Test loss: 0.306988
#
# Epoch 480
# -------------------------------
# Loss: 0.143662  [    0/ 8000 samples]
# Loss: 0.141590  [ 3200/ 8000 samples]
# Loss: 0.126090  [ 6400/ 8000 samples]
# Average loss: 0.3143
# Test loss: 0.277947
#
# Epoch 481
# -------------------------------
# Loss: 0.199052  [    0/ 8000 samples]
# Loss: 0.116218  [ 3200/ 8000 samples]
# Loss: 0.103304  [ 6400/ 8000 samples]
# Average loss: 0.3040
# Test loss: 0.289075
#
# Epoch 482
# -------------------------------
# Loss: 0.137009  [    0/ 8000 samples]
# Loss: 0.264059  [ 3200/ 8000 samples]
# Loss: 0.099054  [ 6400/ 8000 samples]
# Average loss: 0.3399
# Test loss: 0.361193
#
# Epoch 483
# -------------------------------
# Loss: 0.146607  [    0/ 8000 samples]
# Loss: 0.158567  [ 3200/ 8000 samples]
# Loss: 0.135280  [ 6400/ 8000 samples]
# Average loss: 0.3223
# Test loss: 0.310146
#
# Epoch 484
# -------------------------------
# Loss: 0.289681  [    0/ 8000 samples]
# Loss: 0.121654  [ 3200/ 8000 samples]
# Loss: 0.072248  [ 6400/ 8000 samples]
# Average loss: 0.3022
# Test loss: 0.287807
#
# Epoch 485
# -------------------------------
# Loss: 0.142700  [    0/ 8000 samples]
# Loss: 0.148795  [ 3200/ 8000 samples]
# Loss: 0.163717  [ 6400/ 8000 samples]
# Average loss: 0.2975
# Test loss: 0.295413
#
# Epoch 486
# -------------------------------
# Loss: 0.175866  [    0/ 8000 samples]
# Loss: 0.109736  [ 3200/ 8000 samples]
# Loss: 0.131975  [ 6400/ 8000 samples]
# Average loss: 0.3063
# Test loss: 0.303675
#
# Epoch 487
# -------------------------------
# Loss: 0.157377  [    0/ 8000 samples]
# Loss: 0.125109  [ 3200/ 8000 samples]
# Loss: 0.265609  [ 6400/ 8000 samples]
# Average loss: 0.3282
# Test loss: 0.328210
#
# Epoch 488
# -------------------------------
# Loss: 0.184932  [    0/ 8000 samples]
# Loss: 0.127981  [ 3200/ 8000 samples]
# Loss: 0.133814  [ 6400/ 8000 samples]
# Average loss: 0.3090
# Test loss: 0.297710
#
# Epoch 489
# -------------------------------
# Loss: 0.100851  [    0/ 8000 samples]
# Loss: 0.283398  [ 3200/ 8000 samples]
# Loss: 0.193129  [ 6400/ 8000 samples]
# Average loss: 0.3121
# Test loss: 0.283371
#
# Epoch 490
# -------------------------------
# Loss: 0.126677  [    0/ 8000 samples]
# Loss: 0.120287  [ 3200/ 8000 samples]
# Loss: 0.154171  [ 6400/ 8000 samples]
# Average loss: 0.3272
# Test loss: 0.305704
#
# Epoch 491
# -------------------------------
# Loss: 0.129358  [    0/ 8000 samples]
# Loss: 0.139696  [ 3200/ 8000 samples]
# Loss: 0.204885  [ 6400/ 8000 samples]
# Average loss: 0.3215
# Test loss: 0.295566
#
# Epoch 492
# -------------------------------
# Loss: 0.166153  [    0/ 8000 samples]
# Loss: 0.184744  [ 3200/ 8000 samples]
# Loss: 0.268370  [ 6400/ 8000 samples]
# Average loss: 0.3163
# Test loss: 0.308326
#
# Epoch 493
# -------------------------------
# Loss: 0.157776  [    0/ 8000 samples]
# Loss: 0.100449  [ 3200/ 8000 samples]
# Loss: 0.150729  [ 6400/ 8000 samples]
# Average loss: 0.2928
# Test loss: 0.283804
#
# Epoch 494
# -------------------------------
# Loss: 0.144195  [    0/ 8000 samples]
# Loss: 0.199588  [ 3200/ 8000 samples]
# Loss: 0.208790  [ 6400/ 8000 samples]
# Average loss: 0.3133
# Test loss: 0.304302
#
# Epoch 495
# -------------------------------
# Loss: 0.101635  [    0/ 8000 samples]
# Loss: 0.172896  [ 3200/ 8000 samples]
# Loss: 0.170502  [ 6400/ 8000 samples]
# Average loss: 0.2919
# Test loss: 0.337763
#
# Epoch 496
# -------------------------------
# Loss: 0.157596  [    0/ 8000 samples]
# Loss: 0.124629  [ 3200/ 8000 samples]
# Loss: 0.219299  [ 6400/ 8000 samples]
# Average loss: 0.3268
# Test loss: 0.299088
#
# Epoch 497
# -------------------------------
# Loss: 0.142973  [    0/ 8000 samples]
# Loss: 0.104522  [ 3200/ 8000 samples]
# Loss: 0.175755  [ 6400/ 8000 samples]
# Average loss: 0.3277
# Test loss: 0.269801
#
# Epoch 498
# -------------------------------
# Loss: 0.197341  [    0/ 8000 samples]
# Loss: 0.178084  [ 3200/ 8000 samples]
# Loss: 0.126723  [ 6400/ 8000 samples]
# Average loss: 0.3200
# Test loss: 0.322271
#
# Epoch 499
# -------------------------------
# Loss: 0.123016  [    0/ 8000 samples]
# Loss: 0.124286  [ 3200/ 8000 samples]
# Loss: 0.168396  [ 6400/ 8000 samples]
# Average loss: 0.2920
# Test loss: 0.319758
#
# Epoch 500
# -------------------------------
# Loss: 0.117170  [    0/ 8000 samples]
# Loss: 0.183051  [ 3200/ 8000 samples]
# Loss: 0.143881  [ 6400/ 8000 samples]
# Average loss: 0.3012
# Test loss: 0.276934
#
# Done!

# %%
import pandas as pd

# %%
epochs = np.arange(1, len(train_history) + 1)
plt.plot(epochs, pd.Series(train_history).rolling(200).mean(),
         '-o', label = 'train loss')
plt.plot(epochs, pd.Series(train_history).rolling(200).mean(),
         '-o', label = 'test loss')
plt.xlabel('Epoch')
plt.ylabel('MSE Loss')
plt.title('Conditional Flow Matching')
plt.legend()
plt.show()

# %% [markdown]
# ## 4. Evaluating the probability <a name="#prob-eval"></a>

# %% [markdown]
# **Amazing!!** How do these losses translate to the NLL which we were using for training yday?
#
#
# OK, this is _just_ the same as the CNF that we had from this morning, the only difference is that we are training with a different loss function, but we can still _integrate_ the loss function to get the probability.
#
# **TO DO:** [Enumerate the AIs]

# %%
adjoint=False

if adjoint:
    from torchdiffeq import odeint_adjoint as odeint
else:
    from torchdiffeq import odeint

# %%
class condCNF(nn.Module):
    """
    Copying over from `continuous_norm_flow`
    and modifying it to be a conditional distribution
    """
    def __init__(self, net):
        super().__init__()
        self.phi = net

    def forward(self, t, states):
        z = states[0] # masses
        logp_z = states[1]
        cond_inpts = states[2] # GW signal

        batch_size = z.shape[0]

        with torch.set_grad_enabled(True):
            z.requires_grad_(True)

            '''
            TO DO: Define the inputs that we'll use to evaluate the velocity field with
            '''
            X_in = torch.concatenate([z,t*torch.ones(batch_size,1).to(device),cond_inpts],axis=1)
            dz_dt = self.phi(X_in)
            dlogp_z_dt = -trace_df_dz(dz_dt, z).view(batch_size, 1)

        return (dz_dt, dlogp_z_dt)


def trace_df_dz(f, z):
    """Calculates the trace of the Jacobian df/dz.
    Stolen from: https://github.com/rtqichen/ffjord/blob/master/lib/layers/odefunc.py#L13
    """
    sum_diag = 0.
    for i in range(z.shape[1]):
        sum_diag += torch.autograd.grad(f[:, i].sum(), z, create_graph=True)[0].contiguous()[:, i].contiguous()

    return sum_diag.contiguous()

# %%
func = condCNF(phi).to(device)

# %%
for x,y in train_dataloader:
    break

# %%
'''
Clever workaround for some issues w/ CNF w/ additional inputs:
https://github.com/atong01/conditional-flow-matching/blob/main/examples/images/conditional_mnist.ipynb
'''
t0,t1=0,1
logp_diff_t1 = torch.zeros((x.shape[0],1)).float().to(device)

'''
TO DO: What are the bounds for the integration for density evaluation?
'''
z_t, logp_diff_t = odeint(
    lambda t,parital_state: func(t,(*parital_state,y)),
    (x,logp_diff_t1),
    # ... , # Fill in time here
    torch.tensor([t1, t0]).float().to(device), # SOLN
    atol=1e-5,
    rtol=1e-5,
    method='dopri5',
)

# %% [markdown]
# Then to get the NLL, need to
#
# (1) combine the density of the samples under the inverse transformation with (2) the trace of the log Jacobian.
#
# Remember, we did this this morning! You can look at the `01_continuous_flows` nb for inspriation and write up by analogy :)

# %%
'''
Define the base density
'''
p_z0 = torch.distributions.MultivariateNormal(
    loc=torch.zeros(param_dim).to(device), # soln
    covariance_matrix=torch.eye(param_dim).to(device) # soln
)

# %%
log_prob = p_z0.log_prob(z_t[1]) - logp_diff_t[1].squeeze()
nll = - torch.mean(log_prob)
print(nll)
# Out:
# tensor(-2.4213, device='cuda:0', grad_fn=<NegBackward0>)

# %% [markdown]
# Amazing! How does this compare with the log likelihood that we got from the normalizing flows notebook from yesterday?

# %%
def eval_nll(dataloader):
    '''
    Goal: Calculate the NLL across the samples in the dataloader
    '''

    model.eval()

    size = len(dataloader.dataset)
    nll = 0

    logp_diff_t1 = torch.zeros((x.shape[0],1)).float().to(device)

    with torch.no_grad():
        for x,y in dataloader:

            # Integrate the batch backward in time
            z_t, logp_diff_t = odeint(
                                    lambda t,parital_state: func(t,(*parital_state,y)),
                                    (x,logp_diff_t1),
                                    torch.tensor([t1, t0]).type(torch.float32).to(device),
                                    atol=1e-5,
                                    rtol=1e-5,
                                    method='dopri5',
                                )

            # Calulate the log probability
            # YOUR CODE HERE
            log_prob_i = p_z0.log_prob(z_t[1]) - logp_diff_t[1].squeeze()
            nll -= torch.sum(log_prob)

    nll = nll.item() / size

    return nll

# %% [markdown]
# ## 5. Vizualizing samples from the flow <a name="sampling"></a>

# %% [markdown]
# **Vizualize the samples:** Need to integrate in the opposite direction

# %%
noise = torch.randn(x.shape).float().to(device)
logp_diff_t0 = torch.zeros((x.shape[0],1)).float().to(device)

# TO DO: Set up the NODE flow
z_samples, logp_diff_t = odeint(
    lambda t,parital_state: func(t,(*parital_state,y)),
    (noise,logp_diff_t0),
    torch.tensor([t0,t1]).float().to(device),
    atol=1e-5,
    rtol=1e-5,
    method='dopri5',
)

# %% [markdown]
# Following the mpl [docs](https://matplotlib.org/stable/gallery/lines_bars_and_markers/scatter_hist.html#sphx-glr-gallery-lines-bars-and-markers-scatter-hist-py) for the fancy plot layout :)

# %%
t = torch.rand(x.shape[0],1).to(device)
X_in = torch.concatenate([x,t,y],axis=1)
v_t = phi(X_in)

# %%
fig = plt.figure(figsize=(16,9))

# Add a gridspec with 3 rows and two columns and
# a ratio of 1 to 3 to 1 between along the horizontal and
# 1 to 1 on the verical
gs = fig.add_gridspec(2, 3,  width_ratios=(1, 2.5, 1), height_ratios=(1, 1),
                      wspace=0.1, hspace=0.1
                     )
# Create the Axes.
ax11 = fig.add_subplot(gs[1,1])
ax10 = fig.add_subplot(gs[1,0],sharey=ax11)
ax12 = fig.add_subplot(gs[1,2],sharey=ax11)

ax01 = fig.add_subplot(gs[0,1],sharex=ax11)
ax00 = fig.add_subplot(gs[0,0],sharey=ax01)
ax02 = fig.add_subplot(gs[0,2],sharey=ax01)

kwargs = dict(angles='xy',scale_units='xy', scale=30,
              headwidth=2,headlength=2,headaxislength=2,
              width=.004)
ax01.quiver(t.squeeze().cpu(),x[:,0].detach().cpu(), np.ones(t.shape[0]), v_t[:,0].detach().cpu(),
           **kwargs)
ax11.quiver(t.squeeze().cpu(),x[:,1].detach().cpu(), np.ones(t.shape[0]), v_t[:,1].detach().cpu(),
           **kwargs)

ax11.set_xlabel('t',fontsize=20)

'''
Draw the samples @ the beginning + end of the trajectory.
These are the samples we'll transform to plot the posterior
'''
z = torch.randn((t.shape[0],param_dim))

# Turn off the tick labels bc we're sharing the mass axis anyways
for axi in [ax00,ax02,ax10,ax12]:
    axi.tick_params(axis="x", labelbottom=False)
    axi.tick_params(axis="y", labelleft=False)

kwargs = dict(range=(-3,3),orientation='horizontal')
ax00.hist(z[:,0], color='grey', **kwargs)
ax10.hist(z[:,1], color='grey', **kwargs)

# Plot the evolution of these samples thru the velocity field
ax02.hist(z_samples[1,:,0].cpu().detach().numpy(), color='grey', **kwargs)
ax12.hist(z_samples[1,:,1].cpu().detach().numpy(), color='grey', **kwargs)

ax02.hist(x[:,0].detach().cpu(),color='royalblue',histtype='step', **kwargs)
ax12.hist(x[:,1].detach().cpu(),color='royalblue',histtype='step', **kwargs)

# Let the bottom of the histogram align with the left edge of the velocity plot
# https://stackoverflow.com/questions/67685927/how-to-create-a-horizontal-histogram-the-other-way-around
ax00.set_xlim(list(ax00.get_xlim())[::-1])
ax10.set_xlim(list(ax10.get_xlim())[::-1])

ax00.set_title('Initital samples from Gaussian')
ax01.set_title(r'Velocity field $u_\theta(x,y,t)$ from NN')
ax02.set_title('Samples evolved by flow')

ax00.set_ylabel('M0',fontsize=20)
ax10.set_ylabel('M1',fontsize=20)
# Out:
# Text(0, 0.5, 'M1')

# %%
plt.figure(figsize=(3,3))
plt.scatter(*z_samples[1].T.detach().cpu(),100,marker='.',alpha=.9,color='grey',label='evolved by flow')
# plt.scatter(*z_samples[0].T.detach().cpu(),100,marker='.',alpha=.9,color='r',label='noise')

plt.scatter(*waveform_dataset.parameters.T,1,marker='.',alpha=.1)
plt.scatter([],[],100,color='C0',marker='.',alpha=.2,label='target samples') # Let the label be a bit bigger

plt.xlabel('standardized $M_1$')
plt.ylabel('standardized $M_2$')
plt.legend()

# %% [markdown]
# ### Visualize posteriors

# %%
num_posteriors = 3
num_eval_samples = 10_000

func.eval()

for n in range(num_posteriors):

    with torch.no_grad():

        test_x, test_y = test_dataset[n]

        # Sample the posterior
        test_y = test_y.expand(num_eval_samples, *test_y.shape)

        noise = torch.randn((num_eval_samples, param_dim)).float().to(device)
        logp_diff_t0 = torch.zeros((num_eval_samples,1)).float().to(device)

        # TO DO: Set up the NODE
        z_samples, logp_diff_t = odeint(
            lambda t,parital_state: func(t,(*parital_state,test_y)),
            (noise,logp_diff_t0),
            torch.tensor([t0,t1]).float().to(device),
            atol=1e-5,
            rtol=1e-5,
            method='dopri5',
        )

        pred_samples = z_samples[1]

        # Undo the standardization
        parameters_mean = waveform_dataset.parameters_mean
        parameters_std = waveform_dataset.parameters_std

        pred_samples = parameters_std * pred_samples.cpu() + parameters_mean
        truth = parameters_std * test_x.cpu() + parameters_mean
        print(truth)

        # Plot
        corner.corner(pred_samples.numpy(),
                      truths=truth.numpy(),
                      labels=['$m_1$', '$m_2$'],
                      color='C3',truth_color='k'
                     )
        plt.show()
# Out:
# tensor([68.5686, 20.5834])
# tensor([64.3716, 41.4433])
# tensor([69.0853, 57.2359])

# %% [markdown]
# ## 6. BONUS: Movie of the posterior evolution <a name="movie"></a>
#
# OK, let's extend the code to make one of these corner plots a MOVIE!!

# %%
import matplotlib as mpl

# %%
n=0 # Can change for whichever event you like  (!)

viz_timesteps=11

timesteps = torch.linspace(t0, t1, viz_timesteps).float()

with torch.no_grad():

    test_x, test_y = test_dataset[n]

    # Sample the posterior
    test_y = test_y.expand(num_eval_samples, *test_y.shape)
    # pred_samples = model.sample(1, test_y).squeeze(1).cpu().numpy()

    noise = torch.randn((num_eval_samples, param_dim)).float().to(device)
    logp_diff_t0 = torch.zeros((num_eval_samples,1)).float().to(device)

    z_samples, logp_diff_t = odeint(
        lambda t,parital_state: func(t,(*parital_state,test_y)),
        (noise,logp_diff_t0),
        timesteps,
        atol=1e-5,
        rtol=1e-5,
        method='dopri5',
    )

# Undo the standardization
truth = parameters_std * test_x.cpu().numpy() + parameters_mean
truth
# Out:
# /usr/local/lib/python3.10/dist-packages/torchdiffeq/_impl/misc.py:306: UserWarning: t is not on the same device as y0. Coercing to y0.device.
#   warnings.warn("t is not on the same device as y0. Coercing to y0.device.")
# tensor([68.5686, 20.5834])

# %%
import glob
from PIL import Image

# %%
# Make the movie
cmap = mpl.colormaps['coolwarm']
colors = cmap( timesteps )

results_dir = "./figures/tmp"
if not os.path.exists(results_dir):
    os.makedirs(results_dir)

for i,ti,ci in zip(range(viz_timesteps),timesteps,colors):

    pred_samples = z_samples[i]
    pred_samples = parameters_std * pred_samples.cpu() + parameters_mean

    corner.corner(pred_samples.detach().numpy(), truths=truth.numpy(), labels=['$m_1$', '$m_2$'],
                  color=ci,truth_color='k')
    fig=plt.gcf()
    fig.suptitle(f't={ti:.1f}: '+'$p_t(x) = F_{\sharp t}p_0(x)$',color=ci)
    plt.savefig(os.path.join(results_dir, f"fm-posterior-{n}-{ti}.jpg"),
                       pad_inches=0.2, bbox_inches='tight')
    plt.close()

img, *imgs = [Image.open(f) for f in sorted(glob.glob(os.path.join(results_dir, f"fm-posterior-{n}-*.jpg")))]
img.save(fp=f"figures/fm-posterior-{n}.gif", format='GIF', append_images=imgs, save_all=True, duration=250, loop=0)
os.system(f'rm -rf {results_dir}')
# Out:
# 0

# %% [markdown]
# Look in the `figures` directory to see your movie!!
